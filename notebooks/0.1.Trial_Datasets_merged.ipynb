# %% [markdown]
# <div style="text-align: center;">
#   <img src="./imagens/logo_novaims.png" alt="Logo" style="width: 150px; height: auto; margin-bottom: 10px;">
#   <h1 style="margin: 0;"><strong>Machine Learning Project: Amazing International Airlines Inc.</strong></h1>
#   <h2 style="margin: 0;"><strong>Part 1/2: Exploratory Data Analysis</strong></h2>
# </div>
#
# <div style="text-align: left; margin-top: 15px;">
#   <p style="margin: 0;"><strong>Group 51:</strong></p>
#   <ul style="margin: 0; padding-left: 20px;">
#     <li>André Ferreira | 20250398</li>
#     <li>Fausto Gomes | 20221915</li>
#     <li>Maria Francisca Gonçalves | 20221942</li>
#     <li>Miguel Matos | 20221925</li>
#   </ul>
# </div>
#
# ---
# #### <font> Table of Contents </font> <a class="anchor" id='toc'></a>
# 0. [Context](#introduction)
# 1. [Imports](#Imports)
# 2. [Exploratory Data Analysis - Customer Data](#exploratory-data-analysis)
#
# - 2.1. [Data Understanding](#21-data-understanding)
#   - 2.1.1.[Descriptive Analysis](#descriptive-analysis)
#   - 2.1.2.[Visualizations](#visualizations)
#
# - 2.2. [GeoData](#geodata)
#
# - 2.3. [Data Cleaning](#data-cleaning)
#
#
#
# ----

# %% [markdown]
# # <span style="color:#0097b2">0. Context</span>
# [Back to TOC](#toc)

# %% [markdown]
# # <span style="color:#0097b2">1. Imports</span>
# [Back to TOC](#toc)

# %%
from utils.functions import *
from utils.CustomPipeline import CustomPipeline
from pipelines.Missing_values_pipeline import MissingValuesDealer
from pipelines.Outliers_pipeline import OutliersDealer
from pipelines.Encoding_pipeline import EncodingDealer
from pipelines.Scaling_pipeline import ScalingDealer
import warnings

# Suppress this specific warning
warnings.filterwarnings('ignore', 
                       message='X does not have valid feature names',
                       category=UserWarning,
                       module='sklearn.utils.validation')


customer_data = pd.read_csv("../data/cleaned_data/customers_data_cleaned.csv", index_col= 0)
flights_data = pd.read_csv("../data/cleaned_data/flights_data_cleaned.csv", index_col= 0)

pd.set_option("display.max_columns", None)

# %%
data = pd.merge(
    customer_data, 
    flights_data, 
    on='Loyalty#', 
    how='outer' # To keep all clients registered
)

# The merge might create NaNs for customers in df_clean who had zero flight history
# For clustering, we should fill these with 0
features_to_fill = [
    'TotalFlights', 
    'TotalDistance', 
    'TotalPointsAccumulated', 
    'TotalPointsRedeemed'
]
data[features_to_fill] = data[features_to_fill].fillna(0)

# If 'RecencyInMonths' is NaN (from the 'left' merge), it means they never flew. 
# We can keep the 999 we set earlier, or set it again.
data['RecencyInMonths'] = data['RecencyInMonths'].fillna(999)

# %%
flights_data
# Out:
#        Loyalty#  TotalFlights  TotalDistance  TotalPointsAccumulated  \
# 0        100018         229.9       530230.0                53014.30
# 1        100102         247.7       339114.6                33903.96
# 2        100140         216.8       432030.8                43192.58
# 3        100214         112.3       364601.7                36453.77
# 4        100272         186.4       429630.5                42953.25
# ...         ...           ...            ...                     ...
# 16732    999902         267.1       610159.5                61006.55
# 16733    999911           0.0            0.0                    0.00
# 16734    999940          85.5       238578.9                23855.59
# 16735    999982          22.0        52654.0                 5264.00
# 16736    999986         185.8       345117.6                34506.96
#
#        TotalPointsRedeemed LastFlightDate  RecencyInMonths  Pct_Spend_Month_1  \
# 0                  20562.8     2021-12-01         1.018397           0.048421
# 1                  18760.6     2021-12-01         1.018397           0.060884
# 2                   4896.0     2021-11-01         2.003942           0.043443
# 3                  12908.6     2021-12-01         1.018397           0.000000
# 4                  10891.4     2021-11-01         2.003942           0.034945
# ...                    ...            ...              ...                ...
# 16732              10501.8     2021-10-01         3.022339           0.099376
# 16733                  0.0            NaN       999.000000           0.000000
# 16734               5620.0     2021-12-01         1.018397           0.000000
# 16735                  0.0     2021-11-01         2.003942           0.000000
# 16736              18049.4     2021-11-01         2.003942           0.090529
#
#        Pct_Spend_Month_2  Pct_Spend_Month_3  Pct_Spend_Month_4  \
# 0               0.060858           0.074292           0.061981
# 1               0.028640           0.033403           0.049635
# 2               0.000000           0.172908           0.012598
# 3               0.065188           0.057415           0.000000
# 4               0.110526           0.078136           0.041127
# ...                  ...                ...                ...
# 16732           0.089763           0.087597           0.051506
# 16733           0.000000           0.000000           0.000000
# 16734           0.000000           0.114145           0.000000
# 16735           0.000000           0.000000           0.000000
# 16736           0.172165           0.221945           0.065589
#
#        Pct_Spend_Month_5  Pct_Spend_Month_6  Pct_Spend_Month_7  \
# 0               0.000000           0.132689           0.137946
# 1               0.046809           0.080404           0.114205
# 2               0.164527           0.065297           0.164342
# 3               0.000000           0.169642           0.000000
# 4               0.054967           0.167454           0.070783
# ...                  ...                ...                ...
# 16732           0.073032           0.148470           0.099877
# 16733           0.000000           0.000000           0.000000
# 16734           0.000000           0.000000           0.000000
# 16735           0.000000           0.000000           0.000000
# 16736           0.028265           0.000000           0.028748
#
#        Pct_Spend_Month_8  Pct_Spend_Month_9  Pct_Spend_Month_10  \
# 0               0.108319           0.073489            0.065397
# 1               0.014635           0.179591            0.152183
# 2               0.008060           0.079373            0.009099
# 3               0.224220           0.135728            0.089849
# 4               0.179004           0.024562            0.044607
# ...                  ...                ...                 ...
# 16732           0.122778           0.007860            0.081661
# 16733           0.000000           0.000000            0.000000
# 16734           0.121733           0.254003            0.000000
# 16735           0.017857           0.524696            0.000000
# 16736           0.133057           0.112986            0.116810
#
#        Pct_Spend_Month_11  Pct_Spend_Month_12  Flights_per_day
# 0                0.124303            0.112304         0.209954
# 1                0.057872            0.181741         0.226210
# 2                0.135146            0.145208         0.197991
# 3                0.007416            0.250542         0.102557
# 4                0.051625            0.142265         0.170228
# ...                   ...                 ...              ...
# 16732            0.031620            0.106458         0.243927
# 16733            0.000000            0.000000         0.000000
# 16734            0.308023            0.202095         0.078082
# 16735            0.240502            0.216945         0.020091
# 16736            0.029907            0.000000         0.169680
#
# [16737 rows x 20 columns]

# %%
data.head(10)
# Out:
#    Loyalty# First Name Last Name      Customer Name Country Province or State  \
# 0    100011     Amelia      Ross        Amelia Ross  Canada           Ontario
# 1    100012      Ethan  Thompson     Ethan Thompson  Canada            Quebec
# 2    100013      Layla     Young        Layla Young  Canada           Alberta
# 3    100014     Amelia   Bennett     Amelia Bennett  Canada     New Brunswick
# 4    100015   Benjamin    Wilson    Benjamin Wilson  Canada            Quebec
# 5    100016       Emma    Martin        Emma Martin  Canada  British Columbia
# 6    100017      Grace    Fortin       Grace Fortin  Canada  British Columbia
# 7    100018       Mina     Smida         Mina Smida  Canada           Alberta
# 8    100102  Rigoberto   Palacio  Rigoberto Palacio  Canada           Ontario
# 9    100140    Nakesha    Klaass     Nakesha Klaass  Canada  British Columbia
#
#            City   Latitude   Longitude Postal code  Gender Education  \
# 0       Toronto  43.593187  -79.444335     W9D 4Q9  female  Bachelor
# 1   Quebec City  46.759733  -71.141009     Y0C 7D6    male  Bachelor
# 2      Edmonton  53.524829 -113.546357     L3S 9Y3  female  Bachelor
# 3       Moncton  46.051866  -64.825428     G2S 2B6    male  Bachelor
# 4   Quebec City  46.862970  -71.133444     B1Z 8T3  female   College
# 5  Dawson Creek  55.720562 -120.160090     M4A 1E4  female    Master
# 6  Dawson Creek  55.751178 -120.264920     E0K 5I2    male    Master
# 7      Edmonton  53.544388 -113.490930     T9G 1W3  female  Bachelor
# 8       Toronto  43.653225  -79.383186     M1R 4K3    male   College
# 9  Dawson Creek  55.759628 -120.237660     U5I 4F1  female   College
#
#   Location Code   Income Marital Status LoyaltyStatus EnrollmentDateOpening  \
# 0      Suburban      NaN        Married          Star            2017-05-01
# 1      Suburban      NaN         Single          Star            2019-02-27
# 2         Rural      NaN        Married          Star            2017-09-20
# 3         Rural      NaN        Married          Star            2020-11-28
# 4         Urban      NaN        Married          Star            2020-04-09
# 5      Suburban      NaN         Single          Star            2020-07-21
# 6         Urban      NaN        Married          Star            2017-04-11
# 7         Rural  82877.0        Married        Aurora            2019-08-09
# 8         Urban      0.0         Single          Nova            2016-03-09
# 9      Suburban      0.0       Divorced          Nova            2019-07-30
#
#   CancellationDate  Customer Lifetime Value EnrollmentType  rejoined_program  \
# 0       2017-05-01                      NaN       Standard                 0
# 1       2019-02-27                      NaN       Standard                 0
# 2       2017-09-20                      NaN       Standard                 0
# 3       2020-11-28                      NaN       Standard                 0
# 4       2020-04-09                      NaN       Standard                 0
# 5       2020-07-21                      NaN       Standard                 0
# 6       2017-04-11                      NaN       Standard                 0
# 7              NaN                  7919.20       Standard                 0
# 8              NaN                  2887.74       Standard                 0
# 9              NaN                  2838.07       Standard                 0
#
#    Days_in_prog  Cancelled_program  Enrollment_year  Enrollment_month  \
# 0           0.0                  0             2017                 5
# 1           0.0                  0             2019                 2
# 2           0.0                  0             2017                 9
# 3           0.0                  0             2020                11
# 4           0.0                  0             2020                 4
# 5           0.0                  0             2020                 7
# 6           0.0                  0             2017                 4
# 7         874.0                  0             2019                 8
# 8        2122.0                  0             2016                 3
# 9         884.0                  0             2019                 7
#
#    Location_cluster  TotalFlights  TotalDistance  TotalPointsAccumulated  \
# 0                 1           0.0            0.0                    0.00
# 1                 4           0.0            0.0                    0.00
# 2                 5           0.0            0.0                    0.00
# 3                 3           0.0            0.0                    0.00
# 4                 4           0.0            0.0                    0.00
# 5                 5           0.0            0.0                    0.00
# 6                 5           0.0            0.0                    0.00
# 7                 5         229.9       530230.0                53014.30
# 8                 1         247.7       339114.6                33903.96
# 9                 5         216.8       432030.8                43192.58
#
#    TotalPointsRedeemed LastFlightDate  RecencyInMonths  Pct_Spend_Month_1  \
# 0                  0.0            NaN       999.000000                NaN
# 1                  0.0            NaN       999.000000                NaN
# 2                  0.0            NaN       999.000000                NaN
# 3                  0.0            NaN       999.000000                NaN
# 4                  0.0            NaN       999.000000                NaN
# 5                  0.0            NaN       999.000000                NaN
# 6                  0.0            NaN       999.000000                NaN
# 7              20562.8     2021-12-01         1.018397           0.048421
# 8              18760.6     2021-12-01         1.018397           0.060884
# 9               4896.0     2021-11-01         2.003942           0.043443
#
#    Pct_Spend_Month_2  Pct_Spend_Month_3  Pct_Spend_Month_4  Pct_Spend_Month_5  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
# 5                NaN                NaN                NaN                NaN
# 6                NaN                NaN                NaN                NaN
# 7           0.060858           0.074292           0.061981           0.000000
# 8           0.028640           0.033403           0.049635           0.046809
# 9           0.000000           0.172908           0.012598           0.164527
#
#    Pct_Spend_Month_6  Pct_Spend_Month_7  Pct_Spend_Month_8  Pct_Spend_Month_9  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
# 5                NaN                NaN                NaN                NaN
# 6                NaN                NaN                NaN                NaN
# 7           0.132689           0.137946           0.108319           0.073489
# 8           0.080404           0.114205           0.014635           0.179591
# 9           0.065297           0.164342           0.008060           0.079373
#
#    Pct_Spend_Month_10  Pct_Spend_Month_11  Pct_Spend_Month_12  Flights_per_day
# 0                 NaN                 NaN                 NaN              NaN
# 1                 NaN                 NaN                 NaN              NaN
# 2                 NaN                 NaN                 NaN              NaN
# 3                 NaN                 NaN                 NaN              NaN
# 4                 NaN                 NaN                 NaN              NaN
# 5                 NaN                 NaN                 NaN              NaN
# 6                 NaN                 NaN                 NaN              NaN
# 7            0.065397            0.124303            0.112304         0.209954
# 8            0.152183            0.057872            0.181741         0.226210
# 9            0.009099            0.135146            0.145208         0.197991

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16757 entries, 0 to 16756
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Loyalty#                 16757 non-null  int64
#  1   First Name               16757 non-null  object
#  2   Last Name                16757 non-null  object
#  3   Customer Name            16757 non-null  object
#  4   Country                  16757 non-null  object
#  5   Province or State        16757 non-null  object
#  6   City                     16757 non-null  object
#  7   Latitude                 16757 non-null  float64
#  8   Longitude                16757 non-null  float64
#  9   Postal code              16757 non-null  object
#  10  Gender                   16757 non-null  object
#  11  Education                16757 non-null  object
#  12  Location Code            16757 non-null  object
#  13  Income                   16737 non-null  float64
#  14  Marital Status           16757 non-null  object
#  15  LoyaltyStatus            16757 non-null  object
#  16  EnrollmentDateOpening    16757 non-null  object
#  17  CancellationDate         2286 non-null   object
#  18  Customer Lifetime Value  16737 non-null  float64
#  19  EnrollmentType           16757 non-null  object
#  20  rejoined_program         16757 non-null  int64
#  21  Days_in_prog             16757 non-null  float64
#  22  Cancelled_program        16757 non-null  int64
#  23  Enrollment_year          16757 non-null  int64
#  24  Enrollment_month         16757 non-null  int64
#  25  Location_cluster         16757 non-null  int64
#  26  TotalFlights             16757 non-null  float64
#  27  TotalDistance            16757 non-null  float64
#  28  TotalPointsAccumulated   16757 non-null  float64
#  29  TotalPointsRedeemed      16757 non-null  float64
#  30  LastFlightDate           15236 non-null  object
#  31  RecencyInMonths          16757 non-null  float64
#  32  Pct_Spend_Month_1        16737 non-null  float64
#  33  Pct_Spend_Month_2        16737 non-null  float64
#  34  Pct_Spend_Month_3        16737 non-null  float64
#  35  Pct_Spend_Month_4        16737 non-null  float64
#  36  Pct_Spend_Month_5        16737 non-null  float64
#  37  Pct_Spend_Month_6        16737 non-null  float64
#  38  Pct_Spend_Month_7        16737 non-null  float64
#  39  Pct_Spend_Month_8        16737 non-null  float64
#  40  Pct_Spend_Month_9        16737 non-null  float64
#  41  Pct_Spend_Month_10       16737 non-null  float64
#  42  Pct_Spend_Month_11       16737 non-null  float64
#  43  Pct_Spend_Month_12       16737 non-null  float64
#  44  Flights_per_day          16737 non-null  float64
# dtypes: float64(23), int64(6), object(16)
# memory usage: 5.8+ MB

# %% [markdown]
# ### Feature Engeneering

# %%
data["Avg_spent_per_flight"] = np.where(data["EnrollmentDateOpening"] >= "2019-01-01",
                                        data["Customer Lifetime Value"]/(data["Flights_per_day"] * data["Days_in_prog"]),
                                        np.nan)

# %% [markdown]
# "Inf" means infinity, which happens when the divisor is zero, so when "Days_in_prog" or "Flights_per_day" is zero. To handle this, we will feel it with Nan for now.

# %%
data["Avg_spent_per_flight"] = data["Avg_spent_per_flight"].replace(np.inf, np.nan)

# %%
data["Avg_spent_per_flight"].describe()
# Out:
# count      7491.000000
# mean       1960.837518
# std       12811.625099
# min           6.359410
# 25%          51.737521
# 50%         147.920551
# 75%         571.234834
# max      749883.717188
# Name: Avg_spent_per_flight, dtype: float64

# %%
data.head(10)
# Out:
#    Loyalty# First Name Last Name      Customer Name Country Province or State  \
# 0    100011     Amelia      Ross        Amelia Ross  Canada           Ontario
# 1    100012      Ethan  Thompson     Ethan Thompson  Canada            Quebec
# 2    100013      Layla     Young        Layla Young  Canada           Alberta
# 3    100014     Amelia   Bennett     Amelia Bennett  Canada     New Brunswick
# 4    100015   Benjamin    Wilson    Benjamin Wilson  Canada            Quebec
# 5    100016       Emma    Martin        Emma Martin  Canada  British Columbia
# 6    100017      Grace    Fortin       Grace Fortin  Canada  British Columbia
# 7    100018       Mina     Smida         Mina Smida  Canada           Alberta
# 8    100102  Rigoberto   Palacio  Rigoberto Palacio  Canada           Ontario
# 9    100140    Nakesha    Klaass     Nakesha Klaass  Canada  British Columbia
#
#            City   Latitude   Longitude Postal code  Gender Education  \
# 0       Toronto  43.593187  -79.444335     W9D 4Q9  female  Bachelor
# 1   Quebec City  46.759733  -71.141009     Y0C 7D6    male  Bachelor
# 2      Edmonton  53.524829 -113.546357     L3S 9Y3  female  Bachelor
# 3       Moncton  46.051866  -64.825428     G2S 2B6    male  Bachelor
# 4   Quebec City  46.862970  -71.133444     B1Z 8T3  female   College
# 5  Dawson Creek  55.720562 -120.160090     M4A 1E4  female    Master
# 6  Dawson Creek  55.751178 -120.264920     E0K 5I2    male    Master
# 7      Edmonton  53.544388 -113.490930     T9G 1W3  female  Bachelor
# 8       Toronto  43.653225  -79.383186     M1R 4K3    male   College
# 9  Dawson Creek  55.759628 -120.237660     U5I 4F1  female   College
#
#   Location Code   Income Marital Status LoyaltyStatus EnrollmentDateOpening  \
# 0      Suburban      NaN        Married          Star            2017-05-01
# 1      Suburban      NaN         Single          Star            2019-02-27
# 2         Rural      NaN        Married          Star            2017-09-20
# 3         Rural      NaN        Married          Star            2020-11-28
# 4         Urban      NaN        Married          Star            2020-04-09
# 5      Suburban      NaN         Single          Star            2020-07-21
# 6         Urban      NaN        Married          Star            2017-04-11
# 7         Rural  82877.0        Married        Aurora            2019-08-09
# 8         Urban      0.0         Single          Nova            2016-03-09
# 9      Suburban      0.0       Divorced          Nova            2019-07-30
#
#   CancellationDate  Customer Lifetime Value EnrollmentType  rejoined_program  \
# 0       2017-05-01                      NaN       Standard                 0
# 1       2019-02-27                      NaN       Standard                 0
# 2       2017-09-20                      NaN       Standard                 0
# 3       2020-11-28                      NaN       Standard                 0
# 4       2020-04-09                      NaN       Standard                 0
# 5       2020-07-21                      NaN       Standard                 0
# 6       2017-04-11                      NaN       Standard                 0
# 7              NaN                  7919.20       Standard                 0
# 8              NaN                  2887.74       Standard                 0
# 9              NaN                  2838.07       Standard                 0
#
#    Days_in_prog  Cancelled_program  Enrollment_year  Enrollment_month  \
# 0           0.0                  0             2017                 5
# 1           0.0                  0             2019                 2
# 2           0.0                  0             2017                 9
# 3           0.0                  0             2020                11
# 4           0.0                  0             2020                 4
# 5           0.0                  0             2020                 7
# 6           0.0                  0             2017                 4
# 7         874.0                  0             2019                 8
# 8        2122.0                  0             2016                 3
# 9         884.0                  0             2019                 7
#
#    Location_cluster  TotalFlights  TotalDistance  TotalPointsAccumulated  \
# 0                 1           0.0            0.0                    0.00
# 1                 4           0.0            0.0                    0.00
# 2                 5           0.0            0.0                    0.00
# 3                 3           0.0            0.0                    0.00
# 4                 4           0.0            0.0                    0.00
# 5                 5           0.0            0.0                    0.00
# 6                 5           0.0            0.0                    0.00
# 7                 5         229.9       530230.0                53014.30
# 8                 1         247.7       339114.6                33903.96
# 9                 5         216.8       432030.8                43192.58
#
#    TotalPointsRedeemed LastFlightDate  RecencyInMonths  Pct_Spend_Month_1  \
# 0                  0.0            NaN       999.000000                NaN
# 1                  0.0            NaN       999.000000                NaN
# 2                  0.0            NaN       999.000000                NaN
# 3                  0.0            NaN       999.000000                NaN
# 4                  0.0            NaN       999.000000                NaN
# 5                  0.0            NaN       999.000000                NaN
# 6                  0.0            NaN       999.000000                NaN
# 7              20562.8     2021-12-01         1.018397           0.048421
# 8              18760.6     2021-12-01         1.018397           0.060884
# 9               4896.0     2021-11-01         2.003942           0.043443
#
#    Pct_Spend_Month_2  Pct_Spend_Month_3  Pct_Spend_Month_4  Pct_Spend_Month_5  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
# 5                NaN                NaN                NaN                NaN
# 6                NaN                NaN                NaN                NaN
# 7           0.060858           0.074292           0.061981           0.000000
# 8           0.028640           0.033403           0.049635           0.046809
# 9           0.000000           0.172908           0.012598           0.164527
#
#    Pct_Spend_Month_6  Pct_Spend_Month_7  Pct_Spend_Month_8  Pct_Spend_Month_9  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
# 5                NaN                NaN                NaN                NaN
# 6                NaN                NaN                NaN                NaN
# 7           0.132689           0.137946           0.108319           0.073489
# 8           0.080404           0.114205           0.014635           0.179591
# 9           0.065297           0.164342           0.008060           0.079373
#
#    Pct_Spend_Month_10  Pct_Spend_Month_11  Pct_Spend_Month_12  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
# 5                 NaN                 NaN                 NaN
# 6                 NaN                 NaN                 NaN
# 7            0.065397            0.124303            0.112304
# 8            0.152183            0.057872            0.181741
# 9            0.009099            0.135146            0.145208
#
#    Flights_per_day  Avg_spent_per_flight
# 0              NaN                   NaN
# 1              NaN                   NaN
# 2              NaN                   NaN
# 3              NaN                   NaN
# 4              NaN                   NaN
# 5              NaN                   NaN
# 6              NaN                   NaN
# 7         0.209954             43.156382
# 8         0.226210                   NaN
# 9         0.197991             16.215326

# %%
rs_data = data.drop(columns= ["First Name", "Last Name", "Customer Name", "Country", "Province or State", "City", 
                            "Latitude", "Longitude", "Postal code", "Loyalty#", "Gender", "Education", "Location Code", 
                            "Marital Status", "LoyaltyStatus", "EnrollmentDateOpening", "CancellationDate", 
                            "EnrollmentType", "rejoined_program", "Cancelled_program", "LastFlightDate"])

# %%
rs_data.head(10)
# Out:
#     Income  Customer Lifetime Value  Days_in_prog  Enrollment_year  \
# 0      NaN                      NaN           0.0             2017
# 1      NaN                      NaN           0.0             2019
# 2      NaN                      NaN           0.0             2017
# 3      NaN                      NaN           0.0             2020
# 4      NaN                      NaN           0.0             2020
# 5      NaN                      NaN           0.0             2020
# 6      NaN                      NaN           0.0             2017
# 7  82877.0                  7919.20         874.0             2019
# 8      0.0                  2887.74        2122.0             2016
# 9      0.0                  2838.07         884.0             2019
#
#    Enrollment_month  Location_cluster  TotalFlights  TotalDistance  \
# 0                 5                 1           0.0            0.0
# 1                 2                 4           0.0            0.0
# 2                 9                 5           0.0            0.0
# 3                11                 3           0.0            0.0
# 4                 4                 4           0.0            0.0
# 5                 7                 5           0.0            0.0
# 6                 4                 5           0.0            0.0
# 7                 8                 5         229.9       530230.0
# 8                 3                 1         247.7       339114.6
# 9                 7                 5         216.8       432030.8
#
#    TotalPointsAccumulated  TotalPointsRedeemed  RecencyInMonths  \
# 0                    0.00                  0.0       999.000000
# 1                    0.00                  0.0       999.000000
# 2                    0.00                  0.0       999.000000
# 3                    0.00                  0.0       999.000000
# 4                    0.00                  0.0       999.000000
# 5                    0.00                  0.0       999.000000
# 6                    0.00                  0.0       999.000000
# 7                53014.30              20562.8         1.018397
# 8                33903.96              18760.6         1.018397
# 9                43192.58               4896.0         2.003942
#
#    Pct_Spend_Month_1  Pct_Spend_Month_2  Pct_Spend_Month_3  Pct_Spend_Month_4  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
# 5                NaN                NaN                NaN                NaN
# 6                NaN                NaN                NaN                NaN
# 7           0.048421           0.060858           0.074292           0.061981
# 8           0.060884           0.028640           0.033403           0.049635
# 9           0.043443           0.000000           0.172908           0.012598
#
#    Pct_Spend_Month_5  Pct_Spend_Month_6  Pct_Spend_Month_7  Pct_Spend_Month_8  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
# 5                NaN                NaN                NaN                NaN
# 6                NaN                NaN                NaN                NaN
# 7           0.000000           0.132689           0.137946           0.108319
# 8           0.046809           0.080404           0.114205           0.014635
# 9           0.164527           0.065297           0.164342           0.008060
#
#    Pct_Spend_Month_9  Pct_Spend_Month_10  Pct_Spend_Month_11  \
# 0                NaN                 NaN                 NaN
# 1                NaN                 NaN                 NaN
# 2                NaN                 NaN                 NaN
# 3                NaN                 NaN                 NaN
# 4                NaN                 NaN                 NaN
# 5                NaN                 NaN                 NaN
# 6                NaN                 NaN                 NaN
# 7           0.073489            0.065397            0.124303
# 8           0.179591            0.152183            0.057872
# 9           0.079373            0.009099            0.135146
#
#    Pct_Spend_Month_12  Flights_per_day  Avg_spent_per_flight
# 0                 NaN              NaN                   NaN
# 1                 NaN              NaN                   NaN
# 2                 NaN              NaN                   NaN
# 3                 NaN              NaN                   NaN
# 4                 NaN              NaN                   NaN
# 5                 NaN              NaN                   NaN
# 6                 NaN              NaN                   NaN
# 7            0.112304         0.209954             43.156382
# 8            0.181741         0.226210                   NaN
# 9            0.145208         0.197991             16.215326

# %% [markdown]
# # Data Preproc Parameters

# %% [markdown]
# ### Kmeans

# %%
km = KMeans(n_clusters= 6) # Just a random but realistic number of clusters

pipeline = CustomPipeline(MissingValuesDealer(),
                          OutliersDealer(),
                          ScalingDealer(),
                          km)

params = {
    "imputer__imputation_method": ["knn", "simple", "iterative"],
    "imputer__knn_neighbors": np.arange(3, 31),
    "imputer__knn_scaling_method": ["standard", "minmax", "robust"],
    "imputer__simple_strategy_num": ["mean", "median"],
    "imputer__iterative_max_iter": [5, 10, 20, 50],
    "outlier_remover__outlier_method": ["Isolation_Forest", "LOF", "z_score"],
    "outlier_remover__threshold": [2, 2.5, 3, 3.5, 4],
    "outlier_remover__contamination_IF": [0.01, 0.03, 0.05, 0.10, 0.15, 0.25, 0.3, 0.5],
    "outlier_remover__estimators_IF": [50, 100, 150, 200],
    "outlier_remover__max_samples_IF": ["auto", 0.5, 0.7, 1.0],
    "outlier_remover__n_neighbors": [5, 10, 20, 30, 50, 70, 90, 100],
    "outlier_remover__contamination_LOF": [0.01, 0.03, 0.05, 0.10, 0.15, 0.25, 0.3, 0.5],
    "outlier_remover__metric_LOF": ["euclidean", "manhattan", "chebyshev", "minkowski"],
    "scaler__scaler_name": ["standard", "minmax", "robust"]
}


# Use a single train-test split where both are the full dataset
cv = [(np.arange(len(rs_data)), np.arange(len(rs_data)))]

search_km = RandomizedSearchCV(
    pipeline,
    params,
    n_iter=200,
    scoring= clustering_scorer,  
    cv= cv,
    verbose= 3,
    error_score= "raise",
    n_jobs = 4)

# %%
search_km.fit(rs_data)
# Out:
# Fitting 1 folds for each of 200 candidates, totalling 200 fits
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=30, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=0.899 total time=   3.4s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=7, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.692 total time=   6.1s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=6, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.901 total time=   6.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=30, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.883 total time=   3.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=11, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=0.707 total time=   6.1s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=15, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=0.693 total time=   5.9s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=30, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.713 total time=   5.8s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=15, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.916 total time=  18.6s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=7, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=0.694 total time=  19.4s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=10, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.958 total time=  17.4s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=25, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.878 total time=  11.4s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=7, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.902 total time=  15.5s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=30, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.780 total time=   8.3s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=12, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.941 total time=   6.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=12, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=0.875 total time=  16.8s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=5, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.841 total time=  17.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=17, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=0.920 total time=  18.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=15, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.901 total time=   3.4s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=21, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.715 total time=   6.1s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=11, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.763 total time=   9.3s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=26, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.878 total time=   6.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=4, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.836 total time=   2.8s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=17, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.779 total time=   8.4s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=16, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=0.894 total time=  16.7s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=4, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.948 total time=  19.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=10, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.836 total time=  17.7s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=8, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.911 total time=   3.0s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=24, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.875 total time=   4.8s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=5, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.820 total time=   2.9s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=3, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.940 total time=   4.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=21, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.697 total time=   5.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=29, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.970 total time=   3.4s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=23, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.804 total time=  24.4s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=3, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.715 total time=   5.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=19, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.935 total time=  17.2s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=17, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.784 total time=  16.4s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=3, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.854 total time=  30.7s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=7, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.938 total time=   4.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=21, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.889 total time=  16.2s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=24, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.857 total time=  15.6s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=25, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.897 total time=   5.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=12, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.856 total time=  15.4s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=24, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.714 total time=  15.6s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=21, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=0.709 total time=   7.4s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=28, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.876 total time=   4.9s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=8, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.814 total time=  15.8s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=13, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.615 total time=   5.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=28, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.838 total time=   3.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=27, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.908 total time=  28.5s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=6, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.838 total time=  15.7s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=26, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.725 total time=   7.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=28, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.900 total time=  16.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=12, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.937 total time=  17.1s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=25, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.944 total time=   4.2s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=4, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.674 total time=   7.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=22, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.870 total time= 2.8min
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=29, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.942 total time= 2.8min
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=3, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=0.900 total time= 2.8min
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=9, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.909 total time= 2.8min
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=26, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.813 total time=   6.4s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=18, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.913 total time=   3.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=16, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.818 total time=   5.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=9, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.876 total time=   4.1s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=9, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.715 total time=   6.3s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=16, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.936 total time=  20.8s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=15, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.803 total time=  15.4s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=5, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=0.737 total time=  19.9s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=11, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.883 total time=  19.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=28, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.889 total time=   4.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=5, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.720 total time=  19.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=30, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.792 total time=  14.4s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=5, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.865 total time=  16.3s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=21, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.885 total time=  25.9s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=25, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.904 total time=  26.8s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=15, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.903 total time=  17.7s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=16, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.777 total time=  16.4s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=17, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.882 total time=  26.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=10, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.814 total time=  15.3s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=20, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=0.933 total time=  23.6s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=22, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.737 total time=  18.2s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=28, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.677 total time=  15.2s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=14, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.715 total time=   5.4s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=23, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.829 total time=  25.7s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=7, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.737 total time=   6.1s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=11, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.895 total time=   3.1s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=16, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.657 total time=   5.8s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=6, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.617 total time=   5.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=20, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.860 total time=   3.0s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=8, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=0.905 total time=   6.1s
# ...
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=15, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=0.849 total time=   2.6s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=22, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.933 total time=  20.8s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=15, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.871 total time=  16.8s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=29, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.826 total time=   8.1s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=28, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.883 total time=   2.9s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=15, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.848 total time=  16.7s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=28, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.900 total time=   2.8s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=22, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.914 total time=   6.4s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=6, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.897 total time=   3.9s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=30, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.931 total time=  18.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=25, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.688 total time=   7.3s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=22, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.869 total time=  15.7s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=9, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.878 total time=  16.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=30, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.836 total time=   2.9s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=13, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.855 total time=   3.1s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=24, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.686 total time=   6.7s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=3, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.723 total time=   8.7s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=9, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.707 total time=   5.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=5, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=0.844 total time=  16.8s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=11, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.927 total time=   3.5s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=14, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.826 total time=  26.5s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=26, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.952 total time=  16.8s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=29, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.924 total time=   5.4s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=19, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.726 total time=   6.2s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=21, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.887 total time=  14.6s
# RandomizedSearchCV(cv=[(array([    0,     1,     2, ..., 16754, 16755, 16756]),
#                         array([    0,     1,     2, ..., 16754, 16755, 16756]))],
#                    error_score='raise',
#                    estimator=CustomPipeline(imputer=MissingValuesDealer(),
#                                             model=KMeans(n_clusters=6),
#                                             outlier_remover=OutliersDealer(),
#                                             scaler=ScalingDealer()),
#                    n_iter=200, n_jobs=4,
#                    param_distributions={'imputer__imputation_method': ['knn',
#                                                                        'simple',
#                                                                        'iter...
#                                         'outlier_remover__metric_LOF': ['euclidean',
#                                                                         'manhattan',
#                                                                         'chebyshev',
#                                                                         'minkowski'],
#                                         'outlier_remover__n_neighbors': [5, 10,
#                                                                          20, 30,
#                                                                          50, 70,
#                                                                          90,
#                                                                          100],
#                                         'outlier_remover__outlier_method': ['Isolation_Forest',
#                                                                             'LOF',
#                                                                             'z_score'],
#                                         'outlier_remover__threshold': [2, 2.5,
#                                                                        3, 3.5,
#                                                                        4],
#                                         'scaler__scaler_name': ['standard',
#                                                                 'minmax',
#                                                                 'robust']},
#                    scoring=<function clustering_scorer at 0x281449760>,
#                    verbose=3)

# %%
#km_params = pd.DataFrame(search_km.cv_results_)
#km_params.to_csv("../data/models_preproc_data/km_params.csv")
km_params = pd.read_csv("../data/models_preproc_data/km_params.csv", index_col= 0)

km_params.sort_values(by="rank_test_score", ascending= True).head()
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 34        0.361864           0.0         3.019255             0.0
# 93        0.177451           0.0         2.967490             0.0
# 9         7.671202           0.0         9.688294             0.0
# 194       7.661502           0.0         9.116570             0.0
# 127       8.233125           0.0        13.285826             0.0
#
#     param_scaler__scaler_name  param_outlier_remover__threshold  \
# 34                     minmax                               4.0
# 93                   standard                               2.0
# 9                    standard                               4.0
# 194                    minmax                               4.0
# 127                    minmax                               4.0
#
#     param_outlier_remover__outlier_method  param_outlier_remover__n_neighbors  \
# 34                       Isolation_Forest                                  90
# 93                       Isolation_Forest                                  10
# 9                                     LOF                                   5
# 194                      Isolation_Forest                                  10
# 127                                   LOF                                   5
#
#     param_outlier_remover__metric_LOF param_outlier_remover__max_samples_IF  \
# 34                          manhattan                                   0.7
# 93                          minkowski                                  auto
# 9                           minkowski                                   1.0
# 194                         euclidean                                   1.0
# 127                         euclidean                                   0.7
#
#      param_outlier_remover__estimators_IF  \
# 34                                     50
# 93                                     50
# 9                                      50
# 194                                    50
# 127                                   200
#
#      param_outlier_remover__contamination_LOF  \
# 34                                       0.03
# 93                                       0.10
# 9                                        0.50
# 194                                      0.30
# 127                                      0.03
#
#      param_outlier_remover__contamination_IF  \
# 34                                      0.50
# 93                                      0.50
# 9                                       0.50
# 194                                     0.25
# 127                                     0.01
#
#     param_imputer__simple_strategy_num param_imputer__knn_scaling_method  \
# 34                                mean                          standard
# 93                                mean                          standard
# 9                               median                            minmax
# 194                             median                            minmax
# 127                             median                            minmax
#
#      param_imputer__knn_neighbors  param_imputer__iterative_max_iter  \
# 34                             29                                  5
# 93                              8                                 20
# 9                              10                                 10
# 194                            26                                 10
# 127                            12                                 10
#
#     param_imputer__imputation_method  \
# 34                            simple
# 93                            simple
# 9                                knn
# 194                              knn
# 127                              knn
#
#                                                 params  split0_test_score  \
# 34   {'scaler__scaler_name': 'minmax', 'outlier_rem...           0.970455
# 93   {'scaler__scaler_name': 'standard', 'outlier_r...           0.958659
# 9    {'scaler__scaler_name': 'standard', 'outlier_r...           0.958452
# 194  {'scaler__scaler_name': 'minmax', 'outlier_rem...           0.951660
# 127  {'scaler__scaler_name': 'minmax', 'outlier_rem...           0.949511
#
#      mean_test_score  std_test_score  rank_test_score
# 34          0.970455             0.0                1
# 93          0.958659             0.0                2
# 9           0.958452             0.0                3
# 194         0.951660             0.0                4
# 127         0.949511             0.0                5

# %% [markdown]
# Best preproc data for Kmeans.

# %%
km_params["params"][34]
# Out:
# "{'scaler__scaler_name': 'minmax', 'outlier_remover__threshold': 4, 'outlier_remover__outlier_method': 'Isolation_Forest', 'outlier_remover__n_neighbors': 90, 'outlier_remover__metric_LOF': 'manhattan', 'outlier_remover__max_samples_IF': 0.7, 'outlier_remover__estimators_IF': 50, 'outlier_remover__contamination_LOF': 0.03, 'outlier_remover__contamination_IF': 0.5, 'imputer__simple_strategy_num': 'mean', 'imputer__knn_scaling_method': 'standard', 'imputer__knn_neighbors': 29, 'imputer__iterative_max_iter': 5, 'imputer__imputation_method': 'simple'}"

# %%
imputer = MissingValuesDealer(imputation_method= "simple", 
                              simple_strategy_num= "mean")

Outliers = OutliersDealer(outlier_method= "Isolation_Forest", 
                          max_samples_IF= 0.7, estimators_IF= 50,
                          contamination_IF= 0.5)

scaler = ScalingDealer(scaler_name= "minmax")

# %%
km_data = imputer.fit_transform(rs_data)
km_data = Outliers.fit_transform(km_data)
km_data = scaler.fit_transform(km_data)

# %% [markdown]
# ### Hierarchical Clustering

# %%
hierar = AgglomerativeClustering(n_clusters = 6) # Just a random but realistic number of clusters

pipeline = CustomPipeline(MissingValuesDealer(),
                          OutliersDealer(),
                          ScalingDealer(),
                          hierar)

params = {
    "imputer__imputation_method": ["knn", "simple", "iterative"],
    "imputer__knn_neighbors": np.arange(3, 31),
    "imputer__knn_scaling_method": ["standard", "minmax", "robust"],
    "imputer__simple_strategy_num": ["mean", "median"],
    "imputer__iterative_max_iter": [5, 10, 20, 50],
    "outlier_remover__outlier_method": ["Isolation_Forest", "LOF", "z_score"],
    "outlier_remover__threshold": [2, 2.5, 3, 3.5, 4],
    "outlier_remover__contamination_IF": [0.01, 0.03, 0.05, 0.10, 0.15, 0.25, 0.3, 0.5],
    "outlier_remover__estimators_IF": [50, 100, 150, 200],
    "outlier_remover__max_samples_IF": ["auto", 0.5, 0.7, 1.0],
    "outlier_remover__n_neighbors": [5, 10, 20, 30, 50, 70, 90, 100],
    "outlier_remover__contamination_LOF": [0.01, 0.03, 0.05, 0.10, 0.15, 0.25, 0.3, 0.5],
    "outlier_remover__metric_LOF": ["euclidean", "manhattan", "chebyshev", "minkowski"],
    "scaler__scaler_name": ["standard", "minmax", "robust"]
}


# Use a single train-test split where both are the full dataset
cv = [(np.arange(len(rs_data)), np.arange(len(rs_data)))]

search_hierar = RandomizedSearchCV(
    pipeline,
    params,
    n_iter=200,
    scoring= clustering_scorer,  
    cv= cv,
    verbose= 3,
    error_score= "raise",
    n_jobs = 4)

# %%
search_hierar.fit(rs_data)
# Out:
# Fitting 1 folds for each of 200 candidates, totalling 200 fits
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=22, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.889 total time=  19.1s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=19, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.666 total time=  24.7s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=28, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.942 total time=  28.4s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=30, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=0.858 total time=  29.9s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=22, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.623 total time=  18.1s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=21, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.894 total time=  25.0s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=3, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.930 total time=  22.6s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=3, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.690 total time=  19.3s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=16, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.921 total time=  34.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=20, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.844 total time=  31.8s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=22, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.676 total time=  19.2s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=21, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.881 total time=  31.9s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=27, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.804 total time=  20.0s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=22, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=0.936 total time=  18.6s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=15, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.828 total time=  17.4s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=4, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.894 total time=  18.1s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=6, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.709 total time=  31.0s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=24, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.695 total time=  21.9s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=27, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.796 total time=  21.0s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=6, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.886 total time=  30.9s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=4, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.881 total time=  16.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=7, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.810 total time=  17.8s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=12, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.867 total time=  32.9s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=26, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=0.931 total time=  15.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=20, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.807 total time=  16.3s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=19, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.935 total time=  40.7s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=19, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.842 total time=  27.0s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=8, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.691 total time=  16.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=17, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=0.888 total time=  15.0s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=24, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.605 total time=  17.3s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=20, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.867 total time=  15.8s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=19, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.786 total time=  26.7s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=7, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.814 total time=  19.0s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=24, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.831 total time=  18.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=18, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=0.886 total time=  30.3s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=27, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.879 total time=  32.3s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=20, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.956 total time=  19.7s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=4, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=0.888 total time=  16.8s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=9, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.908 total time=  27.8s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=5, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.771 total time=  16.5s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=16, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.911 total time=  26.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=29, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.914 total time=  22.9s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=21, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.690 total time=  17.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=17, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.644 total time=  24.2s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=13, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.674 total time=  16.4s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=25, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.895 total time=  16.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=8, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=0.934 total time=  24.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=10, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.930 total time=  29.7s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=29, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=0.918 total time=  16.9s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=20, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.887 total time=  19.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=13, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=0.874 total time=  30.7s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=22, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.703 total time=  26.9s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=30, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.804 total time=  18.8s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=3, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.849 total time=  31.5s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=25, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.843 total time=  42.4s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=13, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.665 total time=  18.6s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=28, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.916 total time=  19.8s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=7, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.894 total time=  15.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=3, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.657 total time=  17.8s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=28, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.858 total time=  25.8s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=3, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.875 total time=  23.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=9, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.895 total time=  15.4s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=3, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.831 total time=  15.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=24, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.686 total time=  29.2s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=9, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.951 total time=  27.3s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=30, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.914 total time=  16.9s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=8, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.637 total time=  18.8s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=11, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=0.878 total time=  16.2s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=28, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.903 total time=  27.4s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=4, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.640 total time=  16.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=10, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.881 total time=  15.6s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=28, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.876 total time=  30.1s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=21, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.828 total time=  16.3s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=4, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=0.906 total time=  36.6s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=16, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.775 total time=  15.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=26, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.946 total time=  14.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=3, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.909 total time=  32.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=26, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=0.889 total time=  19.3s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=27, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.876 total time=  17.2s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=17, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=0.832 total time=  26.5s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=6, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.667 total time=  18.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=20, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=0.866 total time=  16.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=27, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.812 total time=  23.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=29, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.864 total time=  26.7s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=11, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.917 total time=  31.7s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=9, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=0.944 total time=  14.6s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=7, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.866 total time=  27.1s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=21, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=0.649 total time=  29.8s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=5, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.672 total time=  19.0s
# ...
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=27, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.683 total time=  16.9s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=3, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.777 total time=  16.9s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=6, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.578 total time=  17.2s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=17, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=0.700 total time=  19.9s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=12, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.701 total time=  28.6s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=15, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.795 total time=  28.4s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=10, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.691 total time=  16.0s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=29, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=0.888 total time=  16.2s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=15, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.743 total time=  17.8s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=29, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.691 total time=  17.7s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=13, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.925 total time=  30.2s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=4, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=0.722 total time=  19.7s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=8, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.874 total time=  38.5s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=25, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.691 total time=  15.6s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=14, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=0.848 total time=  15.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=9, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.823 total time=  35.0s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=11, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=0.672 total time=  17.9s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=9, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.866 total time=  26.7s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=20, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.935 total time=  26.6s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=6, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=0.876 total time=  15.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=28, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=0.878 total time=  15.9s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=6, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=0.814 total time=  17.0s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=22, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=0.690 total time=  15.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=28, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=0.865 total time=  37.8s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=16, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=0.878 total time=  22.3s
# RandomizedSearchCV(cv=[(array([    0,     1,     2, ..., 16754, 16755, 16756]),
#                         array([    0,     1,     2, ..., 16754, 16755, 16756]))],
#                    error_score='raise',
#                    estimator=CustomPipeline(imputer=MissingValuesDealer(),
#                                             model=AgglomerativeClustering(n_clusters=6),
#                                             outlier_remover=OutliersDealer(),
#                                             scaler=ScalingDealer()),
#                    n_iter=200, n_jobs=4,
#                    param_distributions={'imputer__imputation_method': ['kn...
#                                         'outlier_remover__metric_LOF': ['euclidean',
#                                                                         'manhattan',
#                                                                         'chebyshev',
#                                                                         'minkowski'],
#                                         'outlier_remover__n_neighbors': [5, 10,
#                                                                          20, 30,
#                                                                          50, 70,
#                                                                          90,
#                                                                          100],
#                                         'outlier_remover__outlier_method': ['Isolation_Forest',
#                                                                             'LOF',
#                                                                             'z_score'],
#                                         'outlier_remover__threshold': [2, 2.5,
#                                                                        3, 3.5,
#                                                                        4],
#                                         'scaler__scaler_name': ['standard',
#                                                                 'minmax',
#                                                                 'robust']},
#                    scoring=<function clustering_scorer at 0x281449760>,
#                    verbose=3)

# %%
#hierar_params = pd.DataFrame(search_hierar.cv_results_)
#hierar_params.to_csv("../data/models_preproc_data/hierar_params.csv")
hierar_params = pd.read_csv("../data/models_preproc_data/hierar_params.csv", index_col= 0)

hierar_params.sort_values(by="rank_test_score", ascending= True).head()
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 169       4.936974           0.0         7.465002             0.0
# 36        7.804138           0.0        11.887815             0.0
# 62       12.919422           0.0        14.375455             0.0
# 143       6.537176           0.0         8.433753             0.0
# 91        6.963298           0.0         8.499386             0.0
#
#     param_scaler__scaler_name  param_outlier_remover__threshold  \
# 169                    minmax                               3.5
# 36                   standard                               3.5
# 62                     minmax                               2.0
# 143                    minmax                               3.5
# 91                     minmax                               2.5
#
#     param_outlier_remover__outlier_method  param_outlier_remover__n_neighbors  \
# 169                      Isolation_Forest                                  50
# 36                                    LOF                                  30
# 62                       Isolation_Forest                                  10
# 143                      Isolation_Forest                                   5
# 91                                    LOF                                  10
#
#     param_outlier_remover__metric_LOF param_outlier_remover__max_samples_IF  \
# 169                         chebyshev                                  auto
# 36                          minkowski                                   0.5
# 62                          manhattan                                   0.7
# 143                         euclidean                                   0.5
# 91                          minkowski                                   1.0
#
#      param_outlier_remover__estimators_IF  \
# 169                                    50
# 36                                    150
# 62                                    100
# 143                                   200
# 91                                    100
#
#      param_outlier_remover__contamination_LOF  \
# 169                                      0.15
# 36                                       0.01
# 62                                       0.50
# 143                                      0.05
# 91                                       0.50
#
#      param_outlier_remover__contamination_IF  \
# 169                                     0.50
# 36                                      0.25
# 62                                      0.30
# 143                                     0.30
# 91                                      0.01
#
#     param_imputer__simple_strategy_num param_imputer__knn_scaling_method  \
# 169                               mean                            minmax
# 36                              median                            minmax
# 62                              median                          standard
# 143                               mean                          standard
# 91                              median                            minmax
#
#      param_imputer__knn_neighbors  param_imputer__iterative_max_iter  \
# 169                            18                                  5
# 36                             20                                  5
# 62                              9                                 20
# 143                            11                                 50
# 91                             29                                 20
#
#     param_imputer__imputation_method  \
# 169                           simple
# 36                            simple
# 62                               knn
# 143                           simple
# 91                            simple
#
#                                                 params  split0_test_score  \
# 169  {'scaler__scaler_name': 'minmax', 'outlier_rem...           0.961547
# 36   {'scaler__scaler_name': 'standard', 'outlier_r...           0.955941
# 62   {'scaler__scaler_name': 'minmax', 'outlier_rem...           0.950900
# 143  {'scaler__scaler_name': 'minmax', 'outlier_rem...           0.948176
# 91   {'scaler__scaler_name': 'minmax', 'outlier_rem...           0.947973
#
#      mean_test_score  std_test_score  rank_test_score
# 169         0.961547             0.0                1
# 36          0.955941             0.0                2
# 62          0.950900             0.0                3
# 143         0.948176             0.0                4
# 91          0.947973             0.0                5

# %%
hierar_params["params"][169]
# Out:
# "{'scaler__scaler_name': 'minmax', 'outlier_remover__threshold': 3.5, 'outlier_remover__outlier_method': 'Isolation_Forest', 'outlier_remover__n_neighbors': 50, 'outlier_remover__metric_LOF': 'chebyshev', 'outlier_remover__max_samples_IF': 'auto', 'outlier_remover__estimators_IF': 50, 'outlier_remover__contamination_LOF': 0.15, 'outlier_remover__contamination_IF': 0.5, 'imputer__simple_strategy_num': 'mean', 'imputer__knn_scaling_method': 'minmax', 'imputer__knn_neighbors': 18, 'imputer__iterative_max_iter': 5, 'imputer__imputation_method': 'simple'}"

# %%
imputer = MissingValuesDealer(imputation_method= "simple", 
                              simple_strategy_num= "mean")

Outliers = OutliersDealer(outlier_method= "Isolation_Forest", 
                          max_samples_IF= "auto", estimators_IF= 50,
                          contamination_IF= 0.5)

scaler = ScalingDealer(scaler_name= "minmax")

# %%
hierar_data = imputer.fit_transform(rs_data)
hierar_data = Outliers.fit_transform(hierar_data)
hierar_data = scaler.fit_transform(hierar_data)

# %% [markdown]
# ### DBSCAN

# %%
db = DBSCAN(
    eps=0.5,           
    min_samples=50,    
    metric='euclidean')

pipeline = CustomPipeline(MissingValuesDealer(),
                          OutliersDealer(),
                          ScalingDealer(),
                          db)

params = {
    "imputer__imputation_method": ["knn", "simple", "iterative"],
    "imputer__knn_neighbors": np.arange(3, 31),
    "imputer__knn_scaling_method": ["standard", "minmax", "robust"],
    "imputer__simple_strategy_num": ["mean", "median"],
    "imputer__iterative_max_iter": [5, 10, 20, 50],
    "outlier_remover__outlier_method": ["Isolation_Forest", "LOF", "z_score"],
    "outlier_remover__threshold": [2, 2.5, 3, 3.5, 4],
    "outlier_remover__contamination_IF": [0.01, 0.03, 0.05, 0.10, 0.15, 0.25, 0.3, 0.5],
    "outlier_remover__estimators_IF": [50, 100, 150, 200],
    "outlier_remover__max_samples_IF": ["auto", 0.5, 0.7, 1.0],
    "outlier_remover__n_neighbors": [5, 10, 20, 30, 50, 70, 90, 100],
    "outlier_remover__contamination_LOF": [0.01, 0.03, 0.05, 0.10, 0.15, 0.25, 0.3, 0.5],
    "outlier_remover__metric_LOF": ["euclidean", "manhattan", "chebyshev", "minkowski"],
    "scaler__scaler_name": ["standard", "minmax", "robust"]
}


# Use a single train-test split where both are the full dataset
cv = [(np.arange(len(rs_data)), np.arange(len(rs_data)))]

search_db = RandomizedSearchCV(
    pipeline,
    params,
    n_iter=200,
    scoring= clustering_scorer,  
    cv= cv,
    verbose= 3,
    error_score= "raise",
    n_jobs = 4)

# %%
search_db.fit(rs_data)
# Out:
# Fitting 1 folds for each of 200 candidates, totalling 200 fits
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=30, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-1.000 total time=   1.1s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=14, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=-0.583 total time=   9.7s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=22, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-1.000 total time=  15.9s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=16, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=-1.000 total time=  16.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=8, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=-0.727 total time=  20.7s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=22, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=-1.000 total time=   1.0s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=12, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=-0.582 total time=   7.5s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=27, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=-1.000 total time=  12.9s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=16, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=-0.829 total time=   8.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=3, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=0.157 total time=  21.9s
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=18, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=-1.000 total time=   4.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=28, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-0.762 total time=   9.5s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=26, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=-1.000 total time=   0.9s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=16, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=-0.080 total time=   4.5s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=29, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-0.030 total time=  16.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=28, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=-0.781 total time=  30.3s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=18, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=-1.000 total time=   1.0s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=28, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=-1.000 total time=   1.0s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=5, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=-1.000 total time=   3.7s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=19, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=-1.000 total time=   1.0s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=20, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=-1.000 total time=  13.5s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=15, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=-0.727 total time=  30.6s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=15, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=-1.000 total time=  13.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=14, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-0.456 total time=  14.8s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=12, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=-1.000 total time=   3.4s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=19, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=standard;, score=-0.802 total time=   5.3s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=29, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=-0.275 total time=  16.9s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=30, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=-1.000 total time=  14.3s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=13, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=-0.239 total time=   6.4s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=14, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-1.000 total time=  14.0s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=6, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-1.000 total time=  14.2s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=14, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=-0.793 total time=  17.8s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=9, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=-0.638 total time=  18.0s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=9, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=-1.000 total time=   1.0s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=12, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=-0.569 total time=   5.6s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=9, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=0.130 total time=  20.9s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=16, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=-0.725 total time=  18.7s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=28, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=-1.000 total time=   1.0s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=10, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=-0.288 total time=   5.9s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=17, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=-0.582 total time=   7.4s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=18, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=-0.516 total time=  17.8s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=26, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=-1.000 total time=  13.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=29, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=-0.751 total time=   5.7s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=3, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=-1.000 total time=   3.8s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=12, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=-1.000 total time=  15.2s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=10, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=-1.000 total time=   0.8s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=27, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=-1.000 total time=  15.2s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=17, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=-0.725 total time=  20.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=28, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=-0.558 total time=   6.0s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=4, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=-1.000 total time=   0.9s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=5, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=-0.492 total time=   6.4s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=19, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=-0.730 total time=  17.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=7, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-0.491 total time=   6.2s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=20, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=-1.000 total time=   4.4s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=23, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=-1.000 total time=  13.5s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=19, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=-0.829 total time=   7.6s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=4, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=-0.395 total time=   8.1s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=15, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=-0.770 total time=  18.7s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=29, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=-0.101 total time=   6.1s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=23, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=-0.308 total time=   7.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=20, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=0.127 total time=   9.9s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=7, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-0.536 total time=  16.9s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=10, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=-0.747 total time=  18.9s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=27, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=-1.000 total time=   3.9s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=23, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=-0.742 total time=  29.2s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=8, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=-1.000 total time=   3.7s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=21, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=-1.000 total time=  14.3s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=15, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=-1.000 total time=   3.6s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=50, imputer__knn_neighbors=3, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=robust;, score=-1.000 total time=  15.6s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=6, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=-0.330 total time=  20.5s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=8, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=-0.059 total time=   6.1s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=8, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=-0.511 total time=   6.3s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=30, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=-0.527 total time=   6.0s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=20, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=standard;, score=-0.263 total time=   6.7s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=20, imputer__knn_neighbors=12, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=-0.829 total time=   7.3s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=28, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=-1.000 total time=   3.7s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=11, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=-0.303 total time=   8.2s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=20, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=-0.680 total time=  17.4s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=50, imputer__knn_neighbors=23, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=-1.000 total time=   0.9s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=4, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=-0.788 total time=  19.2s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=24, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=-0.832 total time=   5.8s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=12, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=-0.401 total time=  16.3s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=6, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=-0.495 total time=   5.7s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=13, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=standard;, score=-0.399 total time=   9.6s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=18, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-0.759 total time=   6.9s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=3, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=z_score, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=-1.000 total time=  15.2s
# ...
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=22, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=-0.222 total time=  19.7s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=17, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=-1.000 total time=   3.8s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=5, imputer__knn_neighbors=30, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=-1.000 total time=   1.1s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=27, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=minmax;, score=-1.000 total time=   3.8s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=5, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3, scaler__scaler_name=minmax;, score=-1.000 total time=   1.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=11, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.25, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=-0.309 total time=  31.4s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=13, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=-0.767 total time=   9.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=17, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=10, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=-0.688 total time=  25.8s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=13, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-1.000 total time=   3.7s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=28, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=70, outlier_remover__outlier_method=LOF, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-0.583 total time=   8.5s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=25, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=20, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=-0.786 total time=  16.7s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=18, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.05, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=z_score, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=-1.000 total time=  13.3s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=50, imputer__knn_neighbors=20, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=50, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2.5, scaler__scaler_name=robust;, score=-0.829 total time=   8.0s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=25, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.01, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=-1.000 total time=  12.7s
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=27, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.15, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=LOF, outlier_remover__threshold=4, scaler__scaler_name=robust;, score=-0.197 total time=  12.8s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=17, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.3, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=-0.209 total time=  25.5s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=10, imputer__knn_neighbors=16, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.3, outlier_remover__estimators_IF=50, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=4, scaler__scaler_name=minmax;, score=-0.582 total time=   6.5s
# [CV 1/1] END imputer__imputation_method=iterative, imputer__iterative_max_iter=5, imputer__knn_neighbors=4, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.25, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-0.400 total time=   8.8s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=5, imputer__knn_neighbors=24, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.1, outlier_remover__contamination_LOF=0.01, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3, scaler__scaler_name=robust;, score=-0.610 total time=  18.4s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=10, imputer__knn_neighbors=23, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.5, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=0.7, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=100, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2.5, scaler__scaler_name=minmax;, score=-1.000 total time=   1.0s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=10, imputer__knn_neighbors=18, imputer__knn_scaling_method=standard, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.03, outlier_remover__estimators_IF=150, outlier_remover__max_samples_IF=1.0, outlier_remover__metric_LOF=manhattan, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=2, scaler__scaler_name=minmax;, score=-0.765 total time=  18.8s
# Warning: Only 1 cluster(s) found
# [CV 1/1] END imputer__imputation_method=simple, imputer__iterative_max_iter=20, imputer__knn_neighbors=19, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.15, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=euclidean, outlier_remover__n_neighbors=90, outlier_remover__outlier_method=z_score, outlier_remover__threshold=2, scaler__scaler_name=standard;, score=-1.000 total time=   0.7s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=10, imputer__knn_scaling_method=robust, imputer__simple_strategy_num=mean, outlier_remover__contamination_IF=0.03, outlier_remover__contamination_LOF=0.1, outlier_remover__estimators_IF=200, outlier_remover__max_samples_IF=0.5, outlier_remover__metric_LOF=minkowski, outlier_remover__n_neighbors=30, outlier_remover__outlier_method=LOF, outlier_remover__threshold=3.5, scaler__scaler_name=robust;, score=-0.614 total time=  16.2s
# [CV 1/1] END imputer__imputation_method=knn, imputer__iterative_max_iter=20, imputer__knn_neighbors=4, imputer__knn_scaling_method=minmax, imputer__simple_strategy_num=median, outlier_remover__contamination_IF=0.5, outlier_remover__contamination_LOF=0.05, outlier_remover__estimators_IF=100, outlier_remover__max_samples_IF=auto, outlier_remover__metric_LOF=chebyshev, outlier_remover__n_neighbors=5, outlier_remover__outlier_method=Isolation_Forest, outlier_remover__threshold=3.5, scaler__scaler_name=standard;, score=0.208 total time=  15.1s
# RandomizedSearchCV(cv=[(array([    0,     1,     2, ..., 16754, 16755, 16756]),
#                         array([    0,     1,     2, ..., 16754, 16755, 16756]))],
#                    error_score='raise',
#                    estimator=CustomPipeline(imputer=MissingValuesDealer(),
#                                             model=DBSCAN(min_samples=50),
#                                             outlier_remover=OutliersDealer(),
#                                             scaler=ScalingDealer()),
#                    n_iter=200, n_jobs=4,
#                    param_distributions={'imputer__imputation_method': ['knn',
#                                                                        'simple',
#                                                                        'it...
#                                         'outlier_remover__metric_LOF': ['euclidean',
#                                                                         'manhattan',
#                                                                         'chebyshev',
#                                                                         'minkowski'],
#                                         'outlier_remover__n_neighbors': [5, 10,
#                                                                          20, 30,
#                                                                          50, 70,
#                                                                          90,
#                                                                          100],
#                                         'outlier_remover__outlier_method': ['Isolation_Forest',
#                                                                             'LOF',
#                                                                             'z_score'],
#                                         'outlier_remover__threshold': [2, 2.5,
#                                                                        3, 3.5,
#                                                                        4],
#                                         'scaler__scaler_name': ['standard',
#                                                                 'minmax',
#                                                                 'robust']},
#                    scoring=<function clustering_scorer at 0x281449760>,
#                    verbose=3)

# %%
#db_params_2 = pd.DataFrame(search_db.cv_results_)
#db_params_2.to_csv("../data/models_preproc_data/db_params_2.csv")

db_params = pd.read_csv("../data/models_preproc_data/db_params_2.csv", index_col= 0)

db_params.sort_values(by="rank_test_score", ascending= True).head()
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 197       7.631931           0.0         7.418725             0.0
# 5         9.646527           0.0        12.228397             0.0
# 33        8.922321           0.0        11.969871             0.0
# 63        3.992239           0.0         5.890433             0.0
# 123       7.873188           0.0        10.028026             0.0
#
#     param_scaler__scaler_name  param_outlier_remover__threshold  \
# 197                  standard                               3.5
# 5                      robust                               4.0
# 33                   standard                               2.5
# 63                     robust                               2.0
# 123                    robust                               2.5
#
#     param_outlier_remover__outlier_method  param_outlier_remover__n_neighbors  \
# 197                      Isolation_Forest                                   5
# 5                        Isolation_Forest                                   5
# 33                       Isolation_Forest                                  90
# 63                       Isolation_Forest                                  70
# 123                      Isolation_Forest                                  90
#
#     param_outlier_remover__metric_LOF param_outlier_remover__max_samples_IF  \
# 197                         chebyshev                                  auto
# 5                           minkowski                                   1.0
# 33                          manhattan                                   1.0
# 63                          minkowski                                   0.7
# 123                         euclidean                                  auto
#
#      param_outlier_remover__estimators_IF  \
# 197                                   100
# 5                                     200
# 33                                    200
# 63                                    150
# 123                                    50
#
#      param_outlier_remover__contamination_LOF  \
# 197                                      0.05
# 5                                        0.15
# 33                                       0.15
# 63                                       0.03
# 123                                      0.01
#
#      param_outlier_remover__contamination_IF  \
# 197                                      0.5
# 5                                        0.5
# 33                                       0.5
# 63                                       0.5
# 123                                      0.5
#
#     param_imputer__simple_strategy_num param_imputer__knn_scaling_method  \
# 197                             median                            minmax
# 5                                 mean                          standard
# 33                                mean                            minmax
# 63                              median                            robust
# 123                               mean                            robust
#
#      param_imputer__knn_neighbors  param_imputer__iterative_max_iter  \
# 197                             4                                 20
# 5                               3                                  5
# 33                              9                                 10
# 63                             20                                 50
# 123                            28                                 10
#
#     param_imputer__imputation_method  \
# 197                              knn
# 5                                knn
# 33                               knn
# 63                         iterative
# 123                              knn
#
#                                                 params  split0_test_score  \
# 197  {'scaler__scaler_name': 'standard', 'outlier_r...           0.207777
# 5    {'scaler__scaler_name': 'robust', 'outlier_rem...           0.157372
# 33   {'scaler__scaler_name': 'standard', 'outlier_r...           0.130309
# 63   {'scaler__scaler_name': 'robust', 'outlier_rem...           0.126750
# 123  {'scaler__scaler_name': 'robust', 'outlier_rem...           0.095004
#
#      mean_test_score  std_test_score  rank_test_score
# 197         0.207777             0.0                1
# 5           0.157372             0.0                2
# 33          0.130309             0.0                3
# 63          0.126750             0.0                4
# 123         0.095004             0.0                5

# %%
db_params["params"][197]
# Out:
# "{'scaler__scaler_name': 'standard', 'outlier_remover__threshold': 3.5, 'outlier_remover__outlier_method': 'Isolation_Forest', 'outlier_remover__n_neighbors': 5, 'outlier_remover__metric_LOF': 'chebyshev', 'outlier_remover__max_samples_IF': 'auto', 'outlier_remover__estimators_IF': 100, 'outlier_remover__contamination_LOF': 0.05, 'outlier_remover__contamination_IF': 0.5, 'imputer__simple_strategy_num': 'median', 'imputer__knn_scaling_method': 'minmax', 'imputer__knn_neighbors': 4, 'imputer__iterative_max_iter': 20, 'imputer__imputation_method': 'knn'}"

# %%
imputer = MissingValuesDealer(imputation_method= "knn", 
                              knn_neighbors= 4,
                              )

Outliers = OutliersDealer(outlier_method= "Isolation_Forest", 
                          max_samples_IF= "auto", estimators_IF= 100,
                          contamination_IF= 0.5)

scaler = ScalingDealer(scaler_name= "standard")

# %%
db_data = imputer.fit_transform(rs_data)
db_data = Outliers.fit_transform(db_data)
db_data = scaler.fit_transform(db_data)

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Variables Correlations

# %% [markdown]
# ### Kmeans

# %% [markdown]
# We'll start with a simple, but important step, of checking the features correlations

# %%
corr = km_data.corr(method="pearson")
corr = corr.round(2)

mask_annot = np.absolute(corr.values) >= 0.5
annot = np.where(mask_annot, corr.values, np.full(corr.shape,"")) 


fig = plt.figure(figsize=(15, 10))

sns.heatmap(data=corr, 
            annot=annot, # Specify custom annotation
            fmt='s', # The annotation matrix now has strings, so we need to explicitly say this
            vmin=-1, vmax=1, 
            center=0, # Center the colormap at zero
            square=True, # Make each cell square-shaped
            linewidths=.5, # Add lines between cells
            cmap='PiYG' # Diverging color map
            )

plt.show()

# %% [markdown]
# Correlation Analysis:
#
# - "Flights_per_day", "Days_in_prog", "TotalFlights", "TotalDistance", "TotalPointsAccumulated" are really correlted variables within each other, so it might be useful to drop them for the clustering phase.

# %% [markdown]
# ### Hierarchical Clustering

# %%
corr = hierar_data.corr(method="pearson")
corr = corr.round(2)

mask_annot = np.absolute(corr.values) >= 0.5
annot = np.where(mask_annot, corr.values, np.full(corr.shape,"")) 


fig = plt.figure(figsize=(15, 10))

sns.heatmap(data=corr, 
            annot=annot, # Specify custom annotation
            fmt='s', # The annotation matrix now has strings, so we need to explicitly say this
            vmin=-1, vmax=1, 
            center=0, # Center the colormap at zero
            square=True, # Make each cell square-shaped
            linewidths=.5, # Add lines between cells
            cmap='PiYG' # Diverging color map
            )

plt.show()

# %% [markdown]
# Correlation Analysis:
#
# - "Flights_per_day", "Days_in_prog", "TotalFlights", "TotalDistance", "TotalPointsAccumulated" are really correlted variables within each other, so it might be useful to drop them for the clustering phase.

# %% [markdown]
# ### DBSCAN

# %%
corr = db_data.corr(method="pearson")
corr = corr.round(2)

mask_annot = np.absolute(corr.values) >= 0.5
annot = np.where(mask_annot, corr.values, np.full(corr.shape,"")) 


fig = plt.figure(figsize=(15, 10))

sns.heatmap(data=corr, 
            annot=annot, # Specify custom annotation
            fmt='s', # The annotation matrix now has strings, so we need to explicitly say this
            vmin=-1, vmax=1, 
            center=0, # Center the colormap at zero
            square=True, # Make each cell square-shaped
            linewidths=.5, # Add lines between cells
            cmap='PiYG' # Diverging color map
            )

plt.show()

# %% [markdown]
# Correlation Analysis:
#
# - "Flights_per_day", "Days_in_prog", "TotalFlights", "TotalDistance", "TotalPointsAccumulated" are really correlted variables within each other, so it might be useful to drop them for the clustering phase.
