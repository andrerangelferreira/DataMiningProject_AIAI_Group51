# %% [markdown]
# # <span style="color:#0097b2">0. Data</span>
# [Back to TOC](#toc)

# %% [markdown]
# ## <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">Libraries Importation</h3>

# %%
from utils.functions import *

# %% [markdown]
# ## <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">Data Importation</h3>

# %%
data = pd.read_csv("../data/cleaned_data/clustering_data_cleaned.csv", index_col = 'Loyalty#')
behavioral_data = pd.read_csv("../data/clustering_data/behavioral_data.csv", index_col = 'Loyalty#')

# %%
behavioral_data = behavioral_data.copy()

# %%
behavioral_data
# Out:
#           TotalPointsAccumulated  RecencyInMonths  Days_in_prog  \
# Loyalty#
# 100011                       0.0            999.0           0.0
# 100012                       0.0            999.0           0.0
# 100013                       0.0            999.0           0.0
# 100014                       0.0            999.0           0.0
# 100015                       0.0            999.0           0.0
# ...                          ...              ...           ...
# 999995                       0.0            999.0           0.0
# 999996                       0.0            999.0           0.0
# 999997                       0.0            999.0           0.0
# 999998                       0.0            999.0           0.0
# 999999                       0.0            999.0           0.0
#
#           Pct_Spend_Month_1  Pct_Spend_Month_2  Pct_Spend_Month_3  \
# Loyalty#
# 100011             0.038995           0.040009           0.054678
# 100012             0.038995           0.040009           0.054678
# 100013             0.038995           0.040009           0.054678
# 100014             0.038995           0.040009           0.054678
# 100015             0.038995           0.040009           0.054678
# ...                     ...                ...                ...
# 999995             0.038995           0.040009           0.054678
# 999996             0.038995           0.040009           0.054678
# 999997             0.038995           0.040009           0.054678
# 999998             0.038995           0.040009           0.054678
# 999999             0.038995           0.040009           0.054678
#
#           Pct_Spend_Month_4  Pct_Spend_Month_5  Pct_Spend_Month_6  \
# Loyalty#
# 100011             0.048966           0.058884            0.07504
# 100012             0.048966           0.058884            0.07504
# 100013             0.048966           0.058884            0.07504
# 100014             0.048966           0.058884            0.07504
# 100015             0.048966           0.058884            0.07504
# ...                     ...                ...                ...
# 999995             0.048966           0.058884            0.07504
# 999996             0.048966           0.058884            0.07504
# 999997             0.048966           0.058884            0.07504
# 999998             0.048966           0.058884            0.07504
# 999999             0.048966           0.058884            0.07504
#
#           Pct_Spend_Month_7  Pct_Spend_Month_8  Pct_Spend_Month_9  \
# Loyalty#
# 100011             0.079692           0.073238           0.061647
# 100012             0.079692           0.073238           0.061647
# 100013             0.079692           0.073238           0.061647
# 100014             0.079692           0.073238           0.061647
# 100015             0.079692           0.073238           0.061647
# ...                     ...                ...                ...
# 999995             0.079692           0.073238           0.061647
# 999996             0.079692           0.073238           0.061647
# 999997             0.079692           0.073238           0.061647
# 999998             0.079692           0.073238           0.061647
# 999999             0.079692           0.073238           0.061647
#
#           Pct_Spend_Month_10  Pct_Spend_Month_11  Pct_Spend_Month_12  \
# Loyalty#
# 100011              0.059436             0.05796            0.079695
# 100012              0.059436             0.05796            0.079695
# 100013              0.059436             0.05796            0.079695
# 100014              0.059436             0.05796            0.079695
# 100015              0.059436             0.05796            0.079695
# ...                      ...                 ...                 ...
# 999995              0.059436             0.05796            0.079695
# 999996              0.059436             0.05796            0.079695
# 999997              0.059436             0.05796            0.079695
# 999998              0.059436             0.05796            0.079695
# 999999              0.059436             0.05796            0.079695
#
#           PctFlightsWithCompanions  PctPointsSpent
# Loyalty#
# 100011                    0.234242        0.215097
# 100012                    0.234242        0.215097
# 100013                    0.234242        0.215097
# 100014                    0.234242        0.215097
# 100015                    0.234242        0.215097
# ...                            ...             ...
# 999995                    0.234242        0.215097
# 999996                    0.234242        0.215097
# 999997                    0.234242        0.215097
# 999998                    0.234242        0.215097
# 999999                    0.234242        0.215097
#
# [16663 rows x 17 columns]

# %%
behavioral_data_st_scl = StandardScaler().fit_transform(behavioral_data)
behavioral_data_mm_scl = MinMaxScaler().fit_transform(behavioral_data)
behavioral_data_rb_scl = RobustScaler().fit_transform(behavioral_data)

# %% [markdown]
# # <span style="color:#0097b2">1. Modelling</span>
# [Back to TOC](#toc)

# %% [markdown]
# ### Behavioral Data

# %% [markdown]
# ## <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">Standard Scaling</h3>

# %% [markdown]
# ### K-Means

# %%
plot_inertia_and_silhouette(behavioral_data_st_scl)

# %%
kmeans_st_scl = KMeans(n_clusters=4, random_state=42).fit(behavioral_data_st_scl)
data['st_scaled_km_cluster4'] = kmeans_st_scl.predict(behavioral_data_st_scl)
behavioral_data['st_scaled_km_cluster4'] = kmeans_st_scl.predict(behavioral_data_st_scl)

# %% [markdown]
# ### Hierarchichal - Ward

# %%
plot_dendrogram(behavioral_data_st_scl, 'ward')

# %%
data['st_scaled_ward_cluster3'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 3
    ).fit_predict(behavioral_data_st_scl)

behavioral_data['st_scaled_ward_cluster3'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 3
    ).fit_predict(behavioral_data_st_scl)

# %% [markdown]
# ## <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">MinMax Scaling</h3>

# %% [markdown]
# ### K-Means

# %%
plot_inertia_and_silhouette(behavioral_data_mm_scl)

# %%
kmeans_mm_scl = KMeans(n_clusters=4, random_state=42).fit(behavioral_data_mm_scl)
data['mm_scaled_km_cluster4'] = kmeans_mm_scl.predict(behavioral_data_mm_scl)
behavioral_data['mm_scaled_km_cluster4'] = kmeans_mm_scl.predict(behavioral_data_mm_scl)

# %% [markdown]
# ### Hierarchichal - Ward

# %%
plot_dendrogram(behavioral_data_mm_scl, 'ward')

# %%
data['mm_scaled_ward_cluster3'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 3
    ).fit_predict(behavioral_data_mm_scl)

behavioral_data['mm_scaled_ward_cluster3'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 3
    ).fit_predict(behavioral_data_mm_scl)

# %% [markdown]
# ## <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">Robust Scaling</h3>

# %% [markdown]
# ### K-Means

# %%
plot_inertia_and_silhouette(behavioral_data_rb_scl)

# %%
kmeans_rb_scl = KMeans(n_clusters=4, random_state=42).fit(behavioral_data_rb_scl)
data['rb_scaled_km_cluster4'] = kmeans_rb_scl.predict(behavioral_data_rb_scl)
behavioral_data['rb_scaled_km_cluster4'] = kmeans_rb_scl.predict(behavioral_data_rb_scl)

# %% [markdown]
# ### Hierarchichal - Ward

# %%
plot_dendrogram(behavioral_data_rb_scl, 'ward')

# %%
data['rb_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_rb_scl)

behavioral_data['rb_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_rb_scl)

# %% [markdown]
# # <span style="color:#0097b2">1. Filtering</span>
# [Back to TOC](#toc)

# %% [markdown]
# ### <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">(1) First-Examination</h3>

# %% [markdown]
# #### Cluster Visualization 1

# %%
clusters_km = ['st_scaled_km_cluster4', 'mm_scaled_km_cluster4', 'rb_scaled_km_cluster4']

# %%
plot_umap_projections(behavioral_data, clusters_km)

# %%
groupby_mean(behavioral_data, 'rb_scaled_km_cluster4', n_features= 16)
# Out:
# rb_scaled_km_cluster4                0           1             2             3
# TotalPointsAccumulated    20864.385021    0.000000  32648.677301  11145.546027
# RecencyInMonths              11.040533  999.000000      1.479157     19.978712
# Days_in_prog                687.248945  582.224786   1173.550395    636.472000
# Pct_Spend_Month_1             0.067502    0.000514      0.053703      0.239498
# Pct_Spend_Month_2             0.058281    0.000527      0.053700      0.199623
# Pct_Spend_Month_3             0.085521    0.000721      0.072270      0.157463
# Pct_Spend_Month_4             0.065468    0.000646      0.064328      0.111586
# Pct_Spend_Month_5             0.076822    0.000776      0.077096      0.095123
# Pct_Spend_Month_6             0.102114    0.000989      0.096015      0.085724
# Pct_Spend_Month_7             0.087924    0.001051      0.102952      0.060725
# Pct_Spend_Month_8             0.088059    0.000966      0.097541      0.039458
# Pct_Spend_Month_9             0.087259    0.000813      0.085334      0.010800
# Pct_Spend_Month_10            0.093913    0.000784      0.085365      0.000000
# Pct_Spend_Month_11            0.092551    0.000764      0.087766      0.000000
# Pct_Spend_Month_12            0.094587    0.001051      0.123931      0.000000
# PctFlightsWithCompanions      0.251979    0.003088      0.253677      0.268832
# PctPointsSpent                0.299344    0.002836      0.305411      0.279836

# %%
cluster_ward = ['st_scaled_ward_cluster3', 'mm_scaled_ward_cluster3', 'rb_scaled_ward_cluster2']

# %%
plot_umap_projections(behavioral_data, cluster_ward)

# %%
groupby_mean(behavioral_data, 'st_scaled_ward_cluster3', n_features= 16)
# Out:
# st_scaled_ward_cluster3              0           1             2
# TotalPointsAccumulated    17169.841511    0.000000  36913.471852
# RecencyInMonths               2.170612  999.000000      2.259733
# Days_in_prog                425.076205  582.224786   1400.170437
# Pct_Spend_Month_1             0.023959    0.000514      0.071059
# Pct_Spend_Month_2             0.025824    0.000527      0.068666
# Pct_Spend_Month_3             0.027224    0.000721      0.091651
# Pct_Spend_Month_4             0.032025    0.000646      0.077409
# Pct_Spend_Month_5             0.048633    0.000776      0.087775
# Pct_Spend_Month_6             0.083052    0.000989      0.100523
# Pct_Spend_Month_7             0.093161    0.001051      0.104369
# Pct_Spend_Month_8             0.100671    0.000966      0.094082
# Pct_Spend_Month_9             0.101665    0.000813      0.077129
# Pct_Spend_Month_10            0.117011    0.000784      0.071650
# Pct_Spend_Month_11            0.136796    0.000764      0.067650
# Pct_Spend_Month_12            0.209979    0.001051      0.088037
# PctFlightsWithCompanions      0.260563    0.003088      0.251673
# PctPointsSpent                0.303281    0.002836      0.305052

# %% [markdown]
# - Cluster 1 - (Cancelled Program and Don't fly)

# %% [markdown]
# #### Cluster Extraction 1

# %%
# Filter the DataFrame based on cluster labels
no_flights = data[data['rb_scaled_km_cluster4'] == 1]

# %%
no_flights
# Out:
#           Gender   Income  Customer Lifetime Value  EnrollmentType  \
# Loyalty#
# 100011         0  34148.0                  5780.18               0
# 100012         1  34148.0                  5780.18               0
# 100013         0  34148.0                  5780.18               0
# 100014         1  34148.0                  5780.18               0
# 100015         0  34148.0                  5780.18               0
# ...          ...      ...                      ...             ...
# 999995         0  34148.0                  5780.18               0
# 999996         0  34148.0                  5780.18               0
# 999997         1  34148.0                  5780.18               0
# 999998         1  34148.0                  5780.18               0
# 999999         1  34148.0                  5780.18               0
#
#           rejoined_program  Days_in_prog  Cancelled_program  Enrollment_year  \
# Loyalty#
# 100011                   0           0.0                  0             2017
# 100012                   0           0.0                  0             2019
# 100013                   0           0.0                  0             2017
# 100014                   0           0.0                  0             2020
# 100015                   0           0.0                  0             2020
# ...                    ...           ...                ...              ...
# 999995                   0           0.0                  0             2020
# 999996                   0           0.0                  0             2018
# 999997                   0           0.0                  0             2020
# 999998                   0           0.0                  0             2017
# 999999                   0           0.0                  0             2016
#
#           Enrollment_month  Location_cluster  ...  Education_Master  \
# Loyalty#                                      ...
# 100011                   5                 1  ...                 0
# 100012                   2                 4  ...                 0
# 100013                   9                 5  ...                 0
# 100014                  11                 3  ...                 0
# 100015                   4                 4  ...                 0
# ...                    ...               ...  ...               ...
# 999995                   3                 4  ...                 0
# 999996                   9                 1  ...                 0
# 999997                   1                 3  ...                 0
# 999998                   1                 4  ...                 0
# 999999                   3                 5  ...                 0
#
#           Marital_Divorced  Marital_Married  Marital_Single  \
# Loyalty#
# 100011                   0                1               0
# 100012                   0                0               1
# 100013                   0                1               0
# 100014                   0                1               0
# 100015                   0                1               0
# ...                    ...              ...             ...
# 999995                   0                1               0
# 999996                   0                0               1
# 999997                   0                1               0
# 999998                   0                0               1
# 999999                   0                0               1
#
#           st_scaled_km_cluster4  st_scaled_ward_cluster3  \
# Loyalty#
# 100011                        3                        1
# 100012                        3                        1
# 100013                        3                        1
# 100014                        3                        1
# 100015                        3                        1
# ...                         ...                      ...
# 999995                        3                        1
# 999996                        3                        1
# 999997                        3                        1
# 999998                        3                        1
# 999999                        3                        1
#
#           mm_scaled_km_cluster4  mm_scaled_ward_cluster3  \
# Loyalty#
# 100011                        2                        1
# 100012                        2                        1
# 100013                        2                        1
# 100014                        2                        1
# 100015                        2                        1
# ...                         ...                      ...
# 999995                        2                        1
# 999996                        2                        1
# 999997                        2                        1
# 999998                        2                        1
# 999999                        2                        1
#
#           rb_scaled_km_cluster4  rb_scaled_ward_cluster2
# Loyalty#
# 100011                        1                        1
# 100012                        1                        1
# 100013                        1                        1
# 100014                        1                        1
# 100015                        1                        1
# ...                         ...                      ...
# 999995                        1                        1
# 999996                        1                        1
# 999997                        1                        1
# 999998                        1                        1
# 999999                        1                        1
#
# [1517 rows x 62 columns]

# %%
# List of cluster labels to exclude
exclude_clusters = [1]

# Filter the original dataset to exclude rows with specified cluster labels
data_filtered1 = data[~data['rb_scaled_km_cluster4'].isin(exclude_clusters)]

# %%
data_filtered1
# Out:
#           Gender   Income  Customer Lifetime Value  EnrollmentType  \
# Loyalty#
# 100018         0  82877.0                  7919.20               0
# 100102         1      0.0                  2887.74               0
# 100140         0      0.0                  2838.07               0
# 100214         1  42837.0                  4170.57               0
# 100272         0  80979.0                  6622.05               0
# ...          ...      ...                      ...             ...
# 999891         0  59732.0                  3745.37               0
# 999902         1      0.0                  7290.07               0
# 999940         0  21542.0                 20266.50               0
# 999982         1      0.0                  2631.56               0
# 999986         0  20072.0                  8257.01               1
#
#           rejoined_program  Days_in_prog  Cancelled_program  Enrollment_year  \
# Loyalty#
# 100018                   0         874.0                  0             2019
# 100102                   0        2122.0                  0             2016
# 100140                   0         884.0                  0             2019
# 100214                   0        1242.0                  0             2018
# 100272                   0        1816.0                  0             2017
# ...                    ...           ...                ...              ...
# 999891                   0         245.0                  1             2019
# 999902                   0        1681.0                  0             2017
# 999940                   0         523.0                  0             2020
# 999982                   0         177.0                  0             2021
# 999986                   0         320.0                  0             2021
#
#           Enrollment_month  Location_cluster  ...  Loyalty_Nova  Loyalty_Star  \
# Loyalty#                                      ...
# 100018                   8                 5  ...             0             0
# 100102                   3                 1  ...             1             0
# 100140                   7                 5  ...             1             0
# 100214                   8                 2  ...             0             1
# 100272                   1                 1  ...             0             1
# ...                    ...               ...  ...           ...           ...
# 999891                   5                 3  ...             1             0
# 999902                   5                 1  ...             0             0
# 999940                   7                 4  ...             1             0
# 999982                   7                 2  ...             0             1
# 999986                   2                 4  ...             1             0
#
#           Education_Bachelor  Education_College  Education_Doctor  \
# Loyalty#
# 100018                     1                  0                 0
# 100102                     0                  1                 0
# 100140                     0                  1                 0
# 100214                     1                  0                 0
# 100272                     1                  0                 0
# ...                      ...                ...               ...
# 999891                     1                  0                 0
# 999902                     0                  1                 0
# 999940                     1                  0                 0
# 999982                     0                  1                 0
# 999986                     1                  0                 0
#
#           Education_High School or Below  Education_Master  Marital_Divorced  \
# Loyalty#
# 100018                                 0                 0                 0
# 100102                                 0                 0                 0
# 100140                                 0                 0                 1
# 100214                                 0                 0                 0
# 100272                                 0                 0                 1
# ...                                  ...               ...               ...
# 999891                                 0                 0                 0
# 999902                                 0                 0                 0
# 999940                                 0                 0                 0
# 999982                                 0                 0                 0
# 999986                                 0                 0                 0
#
#           Marital_Married  Marital_Single
# Loyalty#
# 100018                  1               0
# 100102                  0               1
# 100140                  0               0
# 100214                  1               0
# 100272                  0               0
# ...                   ...             ...
# 999891                  1               0
# 999902                  1               0
# 999940                  1               0
# 999982                  1               0
# 999986                  1               0
#
# [15146 rows x 56 columns]

# %%
data_filtered1 = data_filtered1.iloc[:, :-6]
data_filtered1
# Out:
#           Gender   Income  Customer Lifetime Value  EnrollmentType  \
# Loyalty#
# 100018         0  82877.0                  7919.20               0
# 100102         1      0.0                  2887.74               0
# 100140         0      0.0                  2838.07               0
# 100214         1  42837.0                  4170.57               0
# 100272         0  80979.0                  6622.05               0
# ...          ...      ...                      ...             ...
# 999891         0  59732.0                  3745.37               0
# 999902         1      0.0                  7290.07               0
# 999940         0  21542.0                 20266.50               0
# 999982         1      0.0                  2631.56               0
# 999986         0  20072.0                  8257.01               1
#
#           rejoined_program  Days_in_prog  Cancelled_program  Enrollment_year  \
# Loyalty#
# 100018                   0         874.0                  0             2019
# 100102                   0        2122.0                  0             2016
# 100140                   0         884.0                  0             2019
# 100214                   0        1242.0                  0             2018
# 100272                   0        1816.0                  0             2017
# ...                    ...           ...                ...              ...
# 999891                   0         245.0                  1             2019
# 999902                   0        1681.0                  0             2017
# 999940                   0         523.0                  0             2020
# 999982                   0         177.0                  0             2021
# 999986                   0         320.0                  0             2021
#
#           Enrollment_month  Location_cluster  ...  Loyalty_Nova  Loyalty_Star  \
# Loyalty#                                      ...
# 100018                   8                 5  ...             0             0
# 100102                   3                 1  ...             1             0
# 100140                   7                 5  ...             1             0
# 100214                   8                 2  ...             0             1
# 100272                   1                 1  ...             0             1
# ...                    ...               ...  ...           ...           ...
# 999891                   5                 3  ...             1             0
# 999902                   5                 1  ...             0             0
# 999940                   7                 4  ...             1             0
# 999982                   7                 2  ...             0             1
# 999986                   2                 4  ...             1             0
#
#           Education_Bachelor  Education_College  Education_Doctor  \
# Loyalty#
# 100018                     1                  0                 0
# 100102                     0                  1                 0
# 100140                     0                  1                 0
# 100214                     1                  0                 0
# 100272                     1                  0                 0
# ...                      ...                ...               ...
# 999891                     1                  0                 0
# 999902                     0                  1                 0
# 999940                     1                  0                 0
# 999982                     0                  1                 0
# 999986                     1                  0                 0
#
#           Education_High School or Below  Education_Master  Marital_Divorced  \
# Loyalty#
# 100018                                 0                 0                 0
# 100102                                 0                 0                 0
# 100140                                 0                 0                 1
# 100214                                 0                 0                 0
# 100272                                 0                 0                 1
# ...                                  ...               ...               ...
# 999891                                 0                 0                 0
# 999902                                 0                 0                 0
# 999940                                 0                 0                 0
# 999982                                 0                 0                 0
# 999986                                 0                 0                 0
#
#           Marital_Married  Marital_Single
# Loyalty#
# 100018                  1               0
# 100102                  0               1
# 100140                  0               0
# 100214                  1               0
# 100272                  0               0
# ...                   ...             ...
# 999891                  1               0
# 999902                  1               0
# 999940                  1               0
# 999982                  1               0
# 999986                  1               0
#
# [15146 rows x 56 columns]

# %%
behavioral_data = behavioral_data.iloc[:, :-6]
behavioral_data

# %% [markdown]
# ### <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">(2) Second-Examination</h3>

# %%
data_filtered1
# Out:
#           Gender   Income  Customer Lifetime Value  EnrollmentType  \
# Loyalty#
# 100018         0  82877.0                  7919.20               0
# 100102         1      0.0                  2887.74               0
# 100140         0      0.0                  2838.07               0
# 100214         1  42837.0                  4170.57               0
# 100272         0  80979.0                  6622.05               0
# ...          ...      ...                      ...             ...
# 999891         0  59732.0                  3745.37               0
# 999902         1      0.0                  7290.07               0
# 999940         0  21542.0                 20266.50               0
# 999982         1      0.0                  2631.56               0
# 999986         0  20072.0                  8257.01               1
#
#           rejoined_program  Days_in_prog  Cancelled_program  Enrollment_year  \
# Loyalty#
# 100018                   0         874.0                  0             2019
# 100102                   0        2122.0                  0             2016
# 100140                   0         884.0                  0             2019
# 100214                   0        1242.0                  0             2018
# 100272                   0        1816.0                  0             2017
# ...                    ...           ...                ...              ...
# 999891                   0         245.0                  1             2019
# 999902                   0        1681.0                  0             2017
# 999940                   0         523.0                  0             2020
# 999982                   0         177.0                  0             2021
# 999986                   0         320.0                  0             2021
#
#           Enrollment_month  Location_cluster  ...  Loyalty_Nova  Loyalty_Star  \
# Loyalty#                                      ...
# 100018                   8                 5  ...             0             0
# 100102                   3                 1  ...             1             0
# 100140                   7                 5  ...             1             0
# 100214                   8                 2  ...             0             1
# 100272                   1                 1  ...             0             1
# ...                    ...               ...  ...           ...           ...
# 999891                   5                 3  ...             1             0
# 999902                   5                 1  ...             0             0
# 999940                   7                 4  ...             1             0
# 999982                   7                 2  ...             0             1
# 999986                   2                 4  ...             1             0
#
#           Education_Bachelor  Education_College  Education_Doctor  \
# Loyalty#
# 100018                     1                  0                 0
# 100102                     0                  1                 0
# 100140                     0                  1                 0
# 100214                     1                  0                 0
# 100272                     1                  0                 0
# ...                      ...                ...               ...
# 999891                     1                  0                 0
# 999902                     0                  1                 0
# 999940                     1                  0                 0
# 999982                     0                  1                 0
# 999986                     1                  0                 0
#
#           Education_High School or Below  Education_Master  Marital_Divorced  \
# Loyalty#
# 100018                                 0                 0                 0
# 100102                                 0                 0                 0
# 100140                                 0                 0                 1
# 100214                                 0                 0                 0
# 100272                                 0                 0                 1
# ...                                  ...               ...               ...
# 999891                                 0                 0                 0
# 999902                                 0                 0                 0
# 999940                                 0                 0                 0
# 999982                                 0                 0                 0
# 999986                                 0                 0                 0
#
#           Marital_Married  Marital_Single
# Loyalty#
# 100018                  1               0
# 100102                  0               1
# 100140                  0               0
# 100214                  1               0
# 100272                  0               0
# ...                   ...             ...
# 999891                  1               0
# 999902                  1               0
# 999940                  1               0
# 999982                  1               0
# 999986                  1               0
#
# [15146 rows x 56 columns]

# %%
data_filtered11 = data_filtered1.copy()
behavioral_data_1 = data_filtered11[behavioral_data.columns.to_list()]

# %%
behavioral_data_1_st_scl = StandardScaler().fit_transform(behavioral_data_1)
behavioral_data_1_mm_scl = MinMaxScaler().fit_transform(behavioral_data_1)
behavioral_data_1_rb_scl = RobustScaler().fit_transform(behavioral_data_1)

# %% [markdown]
# #### Cluster Modelling 2

# %% [markdown]
# ## <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">Standard Scaling</h3>

# %%
plot_inertia_and_silhouette(behavioral_data_1_st_scl)

# %%
kmeans_st_scl = KMeans(n_clusters=3, random_state=42).fit(behavioral_data_1_st_scl)
data_filtered11['st_scaled_km_cluster3'] = kmeans_st_scl.predict(behavioral_data_1_st_scl)
behavioral_data_1['st_scaled_km_cluster3'] = kmeans_st_scl.predict(behavioral_data_1_st_scl)

# %%
plot_dendrogram(behavioral_data_1_st_scl, 'ward')

# %%
data_filtered11['st_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_1_st_scl)

behavioral_data_1['st_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_1_st_scl)

# %% [markdown]
# ## <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">Min Max Scaling</h3>

# %%
plot_inertia_and_silhouette(behavioral_data_1_mm_scl)

# %%
kmeans_mm_scl = KMeans(n_clusters=3, random_state=42).fit(behavioral_data_1_mm_scl)
data_filtered11['mm_scaled_km_cluster3'] = kmeans_mm_scl.predict(behavioral_data_1_mm_scl)
behavioral_data_1['mm_scaled_km_cluster3'] = kmeans_mm_scl.predict(behavioral_data_1_mm_scl)

# %%
plot_dendrogram(behavioral_data_1_mm_scl, 'ward')

# %%
data_filtered11['mm_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_1_mm_scl)


behavioral_data_1['mm_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_1_mm_scl)

# %% [markdown]
# ## <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">Robust Scaling</h3>

# %%
plot_inertia_and_silhouette(behavioral_data_1_rb_scl)

# %%
kmeans_rb_scl = KMeans(n_clusters=2, random_state=42).fit(behavioral_data_1_rb_scl)
data_filtered11['rb_scaled_km_cluster2'] = kmeans_rb_scl.predict(behavioral_data_1_rb_scl)
behavioral_data_1['rb_scaled_km_cluster2'] = kmeans_rb_scl.predict(behavioral_data_1_rb_scl)

# %%
plot_dendrogram(behavioral_data_1_rb_scl, 'ward')

# %%
data_filtered11['rb_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_1_rb_scl)

behavioral_data_1['rb_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_1_rb_scl)

# %% [markdown]
# #### Cluster Visualization 2

# %%
cluster_filter1 = ["st_scaled_km_cluster3",	"st_scaled_ward_cluster2", 
                   "mm_scaled_km_cluster3", "mm_scaled_ward_cluster2",
                   "rb_scaled_km_cluster2",	"rb_scaled_ward_cluster2"]

# %%
plot_umap_projections(behavioral_data_1, cluster_filter1)

# %%
groupby_mean(behavioral_data_1, 'mm_scaled_ward_cluster2', n_features= 16)
# Out:
# mm_scaled_ward_cluster2              0             1
# TotalPointsAccumulated    39091.757848  16051.922152
# RecencyInMonths               1.618881      3.556156
# Days_in_prog               1524.695871    333.651823
# Pct_Spend_Month_1             0.064801      0.045772
# Pct_Spend_Month_2             0.063884      0.043719
# Pct_Spend_Month_3             0.084715      0.053592
# Pct_Spend_Month_4             0.073816      0.047836
# Pct_Spend_Month_5             0.086171      0.059075
# Pct_Spend_Month_6             0.103473      0.079876
# Pct_Spend_Month_7             0.110275      0.082547
# Pct_Spend_Month_8             0.097519      0.092145
# Pct_Spend_Month_9             0.079467      0.092271
# Pct_Spend_Month_10            0.074417      0.102970
# Pct_Spend_Month_11            0.070394      0.118543
# Pct_Spend_Month_12            0.091068      0.181654
# PctFlightsWithCompanions      0.252195      0.257855
# PctPointsSpent                0.301402      0.311398

# %% [markdown]
# - Cluster 1 - More recent customers, as they have less days in the program, but they spent most of their flights on the last 4 months (from 9 to 12)

# %% [markdown]
# #### Cluster Extraction 2

# %%
# Filter the DataFrame based on cluster labels
new_9_to_12_travelers = data_filtered11[data_filtered11['mm_scaled_ward_cluster2'] == 1]
len(new_9_to_12_travelers)
# Out:
# 4828

# %%
# List of cluster labels to exclude
exclude_clusters = [1]

# Filter the original dataset to exclude rows with specified cluster labels
data_filter2 = data_filtered11[~data_filtered11['mm_scaled_ward_cluster2'].isin(exclude_clusters)]

# %%
data_filter2
# Out:
#           Gender   Income  Customer Lifetime Value  EnrollmentType  \
# Loyalty#
# 100018         0  82877.0                  7919.20               0
# 100102         1      0.0                  2887.74               0
# 100140         0      0.0                  2838.07               0
# 100214         1  42837.0                  4170.57               0
# 100272         0  80979.0                  6622.05               0
# ...          ...      ...                      ...             ...
# 999524         1      0.0                 14325.15               0
# 999550         0  16181.0                 13736.13               0
# 999631         0  21104.0                  2572.51               0
# 999731         0  69600.0                  2951.29               0
# 999902         1      0.0                  7290.07               0
#
#           rejoined_program  Days_in_prog  Cancelled_program  Enrollment_year  \
# Loyalty#
# 100018                   0         874.0                  0             2019
# 100102                   0        2122.0                  0             2016
# 100140                   0         884.0                  0             2019
# 100214                   0        1242.0                  0             2018
# 100272                   0        1816.0                  0             2017
# ...                    ...           ...                ...              ...
# 999524                   0        1329.0                  0             2018
# 999550                   0        1606.0                  0             2017
# 999631                   0        1796.0                  0             2017
# 999731                   0        1571.0                  1             2016
# 999902                   0        1681.0                  0             2017
#
#           Enrollment_month  Location_cluster  ...  Loyalty_Nova  Loyalty_Star  \
# Loyalty#                                      ...
# 100018                   8                 5  ...             0             0
# 100102                   3                 1  ...             1             0
# 100140                   7                 5  ...             1             0
# 100214                   8                 2  ...             0             1
# 100272                   1                 1  ...             0             1
# ...                    ...               ...  ...           ...           ...
# 999524                   5                 4  ...             0             0
# 999550                   8                 4  ...             0             1
# 999631                   1                 2  ...             0             1
# 999731                   9                 2  ...             0             1
# 999902                   5                 1  ...             0             0
#
#           Education_Bachelor  Education_College  Education_Doctor  \
# Loyalty#
# 100018                     1                  0                 0
# 100102                     0                  1                 0
# 100140                     0                  1                 0
# 100214                     1                  0                 0
# 100272                     1                  0                 0
# ...                      ...                ...               ...
# 999524                     0                  1                 0
# 999550                     0                  0                 1
# 999631                     1                  0                 0
# 999731                     1                  0                 0
# 999902                     0                  1                 0
#
#           Education_High School or Below  Education_Master  Marital_Divorced  \
# Loyalty#
# 100018                                 0                 0                 0
# 100102                                 0                 0                 0
# 100140                                 0                 0                 1
# 100214                                 0                 0                 0
# 100272                                 0                 0                 1
# ...                                  ...               ...               ...
# 999524                                 0                 0                 0
# 999550                                 0                 0                 1
# 999631                                 0                 0                 1
# 999731                                 0                 0                 0
# 999902                                 0                 0                 0
#
#           Marital_Married  Marital_Single
# Loyalty#
# 100018                  1               0
# 100102                  0               1
# 100140                  0               0
# 100214                  1               0
# 100272                  0               0
# ...                   ...             ...
# 999524                  1               0
# 999550                  0               0
# 999631                  0               0
# 999731                  1               0
# 999902                  1               0
#
# [10318 rows x 56 columns]

# %%
data_filter2 = data_filter2.iloc[:, :-6]
behavioral_data_1 = behavioral_data_1.iloc[:,:-6]

# %% [markdown]
# ### <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">(3) Third-Examination</h3>

# %%
data_filter2
# Out:
#           Gender   Income  Customer Lifetime Value  EnrollmentType  \
# Loyalty#
# 100018         0  82877.0                  7919.20               0
# 100102         1      0.0                  2887.74               0
# 100140         0      0.0                  2838.07               0
# 100214         1  42837.0                  4170.57               0
# 100272         0  80979.0                  6622.05               0
# ...          ...      ...                      ...             ...
# 999524         1      0.0                 14325.15               0
# 999550         0  16181.0                 13736.13               0
# 999631         0  21104.0                  2572.51               0
# 999731         0  69600.0                  2951.29               0
# 999902         1      0.0                  7290.07               0
#
#           rejoined_program  Days_in_prog  Cancelled_program  Enrollment_year  \
# Loyalty#
# 100018                   0         874.0                  0             2019
# 100102                   0        2122.0                  0             2016
# 100140                   0         884.0                  0             2019
# 100214                   0        1242.0                  0             2018
# 100272                   0        1816.0                  0             2017
# ...                    ...           ...                ...              ...
# 999524                   0        1329.0                  0             2018
# 999550                   0        1606.0                  0             2017
# 999631                   0        1796.0                  0             2017
# 999731                   0        1571.0                  1             2016
# 999902                   0        1681.0                  0             2017
#
#           Enrollment_month  Location_cluster  ...  Loyalty_Nova  Loyalty_Star  \
# Loyalty#                                      ...
# 100018                   8                 5  ...             0             0
# 100102                   3                 1  ...             1             0
# 100140                   7                 5  ...             1             0
# 100214                   8                 2  ...             0             1
# 100272                   1                 1  ...             0             1
# ...                    ...               ...  ...           ...           ...
# 999524                   5                 4  ...             0             0
# 999550                   8                 4  ...             0             1
# 999631                   1                 2  ...             0             1
# 999731                   9                 2  ...             0             1
# 999902                   5                 1  ...             0             0
#
#           Education_Bachelor  Education_College  Education_Doctor  \
# Loyalty#
# 100018                     1                  0                 0
# 100102                     0                  1                 0
# 100140                     0                  1                 0
# 100214                     1                  0                 0
# 100272                     1                  0                 0
# ...                      ...                ...               ...
# 999524                     0                  1                 0
# 999550                     0                  0                 1
# 999631                     1                  0                 0
# 999731                     1                  0                 0
# 999902                     0                  1                 0
#
#           Education_High School or Below  Education_Master  Marital_Divorced  \
# Loyalty#
# 100018                                 0                 0                 0
# 100102                                 0                 0                 0
# 100140                                 0                 0                 1
# 100214                                 0                 0                 0
# 100272                                 0                 0                 1
# ...                                  ...               ...               ...
# 999524                                 0                 0                 0
# 999550                                 0                 0                 1
# 999631                                 0                 0                 1
# 999731                                 0                 0                 0
# 999902                                 0                 0                 0
#
#           Marital_Married  Marital_Single
# Loyalty#
# 100018                  1               0
# 100102                  0               1
# 100140                  0               0
# 100214                  1               0
# 100272                  0               0
# ...                   ...             ...
# 999524                  1               0
# 999550                  0               0
# 999631                  0               0
# 999731                  1               0
# 999902                  1               0
#
# [10318 rows x 56 columns]

# %%
data_filtered2 = data_filter2.copy()
behavioral_data_2 = data_filtered2[behavioral_data_1.columns.to_list()]

# %%
behavioral_data_2_st_scl = StandardScaler().fit_transform(behavioral_data_2)
behavioral_data_2_mm_scl = MinMaxScaler().fit_transform(behavioral_data_2)
behavioral_data_2_rb_scl = RobustScaler().fit_transform(behavioral_data_2)

# %% [markdown]
# #### Cluster Modelling 3

# %% [markdown]
# ## <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">Standard Scaling</h3>

# %%
plot_inertia_and_silhouette(behavioral_data_2_st_scl)

# %%
kmeans_st_scl = KMeans(n_clusters=2, random_state=42).fit(behavioral_data_2_st_scl)
data_filtered2['st_scaled_km_cluster2'] = kmeans_st_scl.predict(behavioral_data_2_st_scl)
behavioral_data_2['st_scaled_km_cluster2'] = kmeans_st_scl.predict(behavioral_data_2_st_scl)

# %%
plot_dendrogram(behavioral_data_2_st_scl, 'ward')

# %%
data_filtered2['st_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_2_st_scl)

behavioral_data_2['st_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_2_st_scl)

# %% [markdown]
# ## <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">Min Max Scaling</h3>

# %%
plot_inertia_and_silhouette(behavioral_data_2_mm_scl)

# %%
kmeans_mm_scl = KMeans(n_clusters=3, random_state=42).fit(behavioral_data_2_mm_scl)
data_filtered2['mm_scaled_km_cluster3'] = kmeans_mm_scl.predict(behavioral_data_2_mm_scl)
behavioral_data_2['mm_scaled_km_cluster3'] = kmeans_mm_scl.predict(behavioral_data_2_mm_scl)

# %%
plot_dendrogram(behavioral_data_2_mm_scl, 'ward')

# %%
data_filtered2['mm_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_2_mm_scl)

behavioral_data_2['mm_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_2_mm_scl)

# %% [markdown]
# ## <h3 style="color: #333333; background-color: #b0cece; text-align: center; padding: 6px; font-family: 'Arial';">Robust Scaling</h3>

# %%
plot_inertia_and_silhouette(behavioral_data_2_rb_scl)

# %%
kmeans_rb_scl = KMeans(n_clusters=3, random_state=42).fit(behavioral_data_2_rb_scl)
data_filtered2['rb_scaled_km_cluster3'] = kmeans_rb_scl.predict(behavioral_data_2_rb_scl)
behavioral_data_2['rb_scaled_km_cluster3'] = kmeans_rb_scl.predict(behavioral_data_2_rb_scl)

# %%
plot_dendrogram(behavioral_data_2_rb_scl, 'ward')

# %%
data_filtered2['rb_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_2_rb_scl)

behavioral_data_2['rb_scaled_ward_cluster2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(behavioral_data_2_rb_scl)

# %% [markdown]
# #### Cluster Visualization 2

# %%
cluster_filter1 = ["st_scaled_km_cluster2", "st_scaled_ward_cluster2",
                   'mm_scaled_km_cluster3', "mm_scaled_ward_cluster2",
                   "rb_scaled_km_cluster3", "rb_scaled_ward_cluster2"
                   ]

# %%
plot_umap_projections(behavioral_data_2, cluster_filter1)

# %%
groupby_mean(data_filtered2, 'st_scaled_km_cluster2', n_features= 44)
# Out:
# st_scaled_km_cluster2                   0              1
# Gender                           0.515158       0.496120
# Income                       37866.563842   37725.666494
# Customer Lifetime Value       8007.205906    7887.668622
# EnrollmentType                   0.015711       0.016555
# rejoined_program                 0.000000       0.000000
# Days_in_prog                  1593.461828    1471.108467
# Cancelled_program                0.039168       0.009657
# Enrollment_year               2017.096260    2017.469219
# Enrollment_month                 6.676698       6.490947
# Location_cluster                 2.410046       2.463873
# TotalFlights                   182.998429     204.050629
# TotalDistance               350865.696127  422261.876703
# TotalPointsAccumulated       35079.409157   42218.469995
# TotalPointsRedeemed          12776.023766   10531.040955
# RecencyInMonths                  1.948111       1.362321
# Pct_Spend_Month_1                0.076035       0.056046
# Pct_Spend_Month_2                0.078397       0.052574
# Pct_Spend_Month_3                0.098190       0.074213
# Pct_Spend_Month_4                0.084593       0.065417
# Pct_Spend_Month_5                0.096594       0.078048
# Pct_Spend_Month_6                0.102497       0.104234
# Pct_Spend_Month_7                0.061806       0.148045
# Pct_Spend_Month_8                0.096695       0.098162
# Pct_Spend_Month_9                0.080978       0.078290
# Pct_Spend_Month_10               0.075082       0.073900
# Pct_Spend_Month_11               0.071389       0.069619
# Pct_Spend_Month_12               0.077744       0.101452
# Total_Spend_Month_1              8.061297       6.745749
# Total_Spend_Month_2              9.014273       5.816779
# Total_Spend_Month_3             11.118411       7.848319
# Total_Spend_Month_4             10.226466       7.201311
# Total_Spend_Month_5             11.119584       8.624746
# Total_Spend_Month_6             13.950874      10.731195
# Total_Spend_Month_7             11.321376      13.172064
# Total_Spend_Month_8             12.399934      10.378841
# Total_Spend_Month_9             10.087342       8.514571
# Total_Spend_Month_10             8.955079       8.140317
# Total_Spend_Month_11             8.667205       7.085877
# Total_Spend_Month_12            11.344258       9.803449
# TotalFlightsWithCompanions      47.428635      49.354889
# TotalFlightSpend               126.266099     104.063218
# PctFlightsWithCompanions         0.262321       0.244304
# PctPointsSpent                   0.367234       0.250101
# Avg_Flights_per_day              0.212128       0.224067
# Avg_spent_per_flight            56.582162      53.543524

# %% [markdown]
# Cluster 0 - Active Redeemers with Off-Season Travel
#
# - Active user of rewards (36.7% points redeemed)
#
# - No Seasonality
#
# Cluster 1 - Holidays travelers
#
# - 14% of their total spend on july, and 10% on june and december

# %% [markdown]
# #### Cluster Extraction 3 and 4

# %%
# Filter the DataFrame based on cluster labels
active_redeemers = data_filtered2[data_filtered2['st_scaled_km_cluster2'] == 0]

holiday_travelers = data_filtered2[data_filtered2['st_scaled_km_cluster2'] == 1]

# %%
# List of cluster labels to exclude
exclude_clusters = [0,1]

# Filter the original dataset to exclude rows with specified cluster labels
data_filter3 = data_filtered2[~data_filtered2['st_scaled_km_cluster2'].isin(exclude_clusters)]

# %%
data_filter3
# Out:
# Empty DataFrame
# Columns: [Gender, Income, Customer Lifetime Value, EnrollmentType, rejoined_program, Days_in_prog, Cancelled_program, Enrollment_year, Enrollment_month, Location_cluster, TotalFlights, TotalDistance, TotalPointsAccumulated, TotalPointsRedeemed, RecencyInMonths, Pct_Spend_Month_1, Pct_Spend_Month_2, Pct_Spend_Month_3, Pct_Spend_Month_4, Pct_Spend_Month_5, Pct_Spend_Month_6, Pct_Spend_Month_7, Pct_Spend_Month_8, Pct_Spend_Month_9, Pct_Spend_Month_10, Pct_Spend_Month_11, Pct_Spend_Month_12, Total_Spend_Month_1, Total_Spend_Month_2, Total_Spend_Month_3, Total_Spend_Month_4, Total_Spend_Month_5, Total_Spend_Month_6, Total_Spend_Month_7, Total_Spend_Month_8, Total_Spend_Month_9, Total_Spend_Month_10, Total_Spend_Month_11, Total_Spend_Month_12, TotalFlightsWithCompanions, TotalFlightSpend, PctFlightsWithCompanions, PctPointsSpent, Avg_Flights_per_day, Avg_spent_per_flight, Loyalty_Aurora, Loyalty_Nova, Loyalty_Star, Education_Bachelor, Education_College, Education_Doctor, Education_High School or Below, Education_Master, Marital_Divorced, Marital_Married, Marital_Single, st_scaled_km_cluster2, st_scaled_ward_cluster2, mm_scaled_km_cluster3, mm_scaled_ward_cluster2, rb_scaled_km_cluster3, rb_scaled_ward_cluster2]
# Index: []
#
# [0 rows x 62 columns]

# %% [markdown]
# # <span style="color:#0097b2">1. Cluster Extraction</span>
# [Back to TOC](#toc)

# %%
# Define file names for CSV files
file_names = ['../data/behaviour_clusters/no_flights.csv', '../data/behaviour_clusters/new_9_to_12_travelers.csv', 
              '../data/behaviour_clusters/active_redeemers.csv', '../data/behaviour_clusters/holiday_travelers.csv']

# Define dataframes and filenames
datasets = [no_flights, new_9_to_12_travelers, active_redeemers, holiday_travelers]

# Save each subset as a CSV file
for df, file_name in zip(datasets, file_names):
    df.to_csv(file_name)
